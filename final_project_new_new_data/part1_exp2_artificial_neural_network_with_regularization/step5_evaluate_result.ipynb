# %%
import numpy
import pandas
import joblib
import json
import seaborn

import sklearn

# %matplotlib inline

# %% [markdown]
# # Instructions
#
# - Read **the test data** from the CSV file and properly set the index
# - Load the trained model

# %%
data_test = pandas.read_csv('./data/n_high_salary_features.test.csv').set_index('id')
data_test
# Out:
#        social-security-number  house-number     age-group    fnlwgt  \
# id
# 27867               -0.070140     -0.284801 -1.775140e-16  0.245956
# 27868                0.328634     -1.178938 -7.277627e-01 -1.221542
# 27869                1.203952      0.897947  7.168925e-02  0.774717
# 27870                0.130615      0.849030 -1.527215e+00 -0.388883
# 27871                1.436679     -0.486410 -7.277627e-01 -0.063507
# ...                       ...           ...           ...       ...
# 34862               -0.993863     -0.048601 -7.277627e-01  0.834739
# 34863               -0.290510      0.535610  7.168925e-02  0.400111
# 34864               -0.335037     -1.630374 -7.277627e-01  2.330491
# 34865               -1.682173     -0.445180  8.711412e-01  0.580198
# 34866                0.909053     -1.510527  7.168925e-02 -0.806659
#
#        education-num  capitalgain  capitalloss  hoursperweek  workclass  \
# id
# 27867       1.358944    -0.326858    -0.234681     -0.048355        3.0
# 27868      -0.559105    -0.326858    -0.234681     -0.048355        5.0
# 27869       0.975334    -0.326858    -0.234681     -0.048355        3.0
# 27870      -0.175495    -0.326858    -0.234681     -1.189149        4.0
# 27871       0.591724    -0.326858    -0.234681     -0.048355        1.0
# ...              ...          ...          ...           ...        ...
# 34862      -0.175495    -0.326858    -0.234681     -0.048355        1.0
# 34863       0.975334    -0.326858    -0.234681     -0.048355        3.0
# 34864       0.975334    -0.326858    -0.234681     -0.048355        1.0
# 34865      -0.559105    -0.326858    -0.234681      1.092439        3.0
# 34866       1.742553     3.933366    -0.234681      1.092439        3.0
#
#        education  marital-status  occupation  relationship  race  sex  \
# id
# 27867       12.0             0.0         9.0           1.0   4.0  1.0
# 27868       11.0             2.0         2.0           0.0   4.0  1.0
# 27869        9.0             2.0         9.0           0.0   1.0  1.0
# 27870       15.0             4.0         7.0           3.0   1.0  0.0
# 27871        7.0             2.0        10.0           0.0   4.0  1.0
# ...          ...             ...         ...           ...   ...  ...
# 34862       15.0             4.0        10.0           1.0   2.0  1.0
# 34863        9.0             4.0        11.0           3.0   4.0  1.0
# 34864        9.0             2.0         9.0           0.0   4.0  1.0
# 34865       11.0             2.0        13.0           0.0   4.0  1.0
# 34866       14.0             4.0         9.0           1.0   4.0  0.0
#
#        native-country-code  native-country
# id
# 27867                  0.0             1.0
# 27868                 36.0            38.0
# 27869                  1.0             2.0
# 27870                 39.0            34.0
# 27871                 36.0            38.0
# ...                    ...             ...
# 34862                 36.0            38.0
# 34863                  5.0            10.0
# 34864                 23.0            25.0
# 34865                 36.0            38.0
# 34866                 36.0            38.0
#
# [7000 rows x 17 columns]

# %%
data_train = pandas.read_csv('./data/n_high_salary_features.train.csv').set_index('id')
data_train
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 8616                 1.074396      1.285441   0.071689  0.783535
# 21982               -1.534570     -1.103815   0.871141 -0.414340
# 11191               -0.952128      1.541907  -1.527215  0.499810
# 22229               -0.698142      1.208222   0.071689 -0.683323
# 20732               -0.502967     -1.318003   0.871141 -0.277714
# ...                       ...           ...        ...       ...
# 21575                0.248551      1.336455  -1.527215 -0.405358
# 5390                -0.297652      0.539104   0.871141  1.368795
# 860                  0.494586     -1.309268   0.871141 -1.431674
# 15795               -1.138869      0.965033  -1.527215  0.835243
# 23654               -0.053051     -0.799480   1.670593 -0.114799
#
#        education-num  capitalgain  capitalloss  hoursperweek  workclass  \
# id
# 8616        0.975334    -0.326858    -0.234681      1.092439        4.0
# 21982       2.126163    -0.326858     2.877363     -0.048355        1.0
# 11191      -0.559105    -0.326858    -0.234681     -1.189149        3.0
# 22229      -0.559105    -0.326858    -0.234681     -0.048355        3.0
# 20732       0.975334    -0.326858    -0.234681      1.092439        3.0
# ...              ...          ...          ...           ...        ...
# 21575       0.591724    -0.326858    -0.234681     -0.048355        3.0
# 5390       -3.627983    -0.326858    -0.234681     -0.048355        3.0
# 860        -0.175495    -0.326858    -0.234681     -0.048355        3.0
# 15795      -0.175495    -0.326858    -0.234681     -0.048355        6.0
# 23654       1.358944    -0.326858    -0.234681      1.092439        3.0
#
#        education  marital-status  occupation  relationship  race  sex  \
# id
# 8616         9.0             2.0         3.0           0.0   4.0  1.0
# 21982       10.0             2.0         9.0           0.0   4.0  1.0
# 11191       11.0             4.0         7.0           1.0   4.0  0.0
# 22229       11.0             0.0         6.0           2.0   2.0  1.0
# 20732        9.0             2.0        11.0           0.0   4.0  1.0
# ...          ...             ...         ...           ...   ...  ...
# 21575        7.0             4.0        11.0           1.0   4.0  1.0
# 5390        13.0             2.0         7.0           0.0   4.0  1.0
# 860         15.0             2.0         0.0           0.0   4.0  1.0
# 15795       15.0             4.0         6.0           3.0   4.0  0.0
# 23654       12.0             2.0         3.0           0.0   4.0  1.0
#
#        native-country-code  native-country  label
# id
# 8616                  36.0            38.0    1.0
# 21982                 36.0            38.0    1.0
# 11191                 36.0            38.0    0.0
# 22229                 36.0            38.0    0.0
# 20732                 36.0            38.0    1.0
# ...                    ...             ...    ...
# 21575                 36.0            38.0    0.0
# 5390                  23.0            25.0    0.0
# 860                   36.0            38.0    1.0
# 15795                 36.0            38.0    0.0
# 23654                 36.0            38.0    1.0
#
# [20900 rows x 18 columns]

# %%
model = joblib.load('model/model.joblib')
model
# Out:
# MLPClassifier(activation='logistic', alpha=0.007, batch_size=32,
#               hidden_layer_sizes=(20, 10), learning_rate_init=0.1,
#               max_iter=2000, momentum=0.0, nesterovs_momentum=False,
#               random_state=0, solver='sgd', validation_fraction=0.0)

# %% [markdown]
# # Instructions
# - Calculate and add the `prediction` column to the dataframe of test data
# - Write the dataframe to `./results/predictions.test.csv`

# %%
data_test['prediction'] = model.predict(data_test.drop([], axis='columns'))
data_test
# Out:
#        social-security-number  house-number     age-group    fnlwgt  \
# id
# 27867               -0.070140     -0.284801 -1.775140e-16  0.245956
# 27868                0.328634     -1.178938 -7.277627e-01 -1.221542
# 27869                1.203952      0.897947  7.168925e-02  0.774717
# 27870                0.130615      0.849030 -1.527215e+00 -0.388883
# 27871                1.436679     -0.486410 -7.277627e-01 -0.063507
# ...                       ...           ...           ...       ...
# 34862               -0.993863     -0.048601 -7.277627e-01  0.834739
# 34863               -0.290510      0.535610  7.168925e-02  0.400111
# 34864               -0.335037     -1.630374 -7.277627e-01  2.330491
# 34865               -1.682173     -0.445180  8.711412e-01  0.580198
# 34866                0.909053     -1.510527  7.168925e-02 -0.806659
#
#        education-num  capitalgain  capitalloss  hoursperweek  workclass  \
# id
# 27867       1.358944    -0.326858    -0.234681     -0.048355        3.0
# 27868      -0.559105    -0.326858    -0.234681     -0.048355        5.0
# 27869       0.975334    -0.326858    -0.234681     -0.048355        3.0
# 27870      -0.175495    -0.326858    -0.234681     -1.189149        4.0
# 27871       0.591724    -0.326858    -0.234681     -0.048355        1.0
# ...              ...          ...          ...           ...        ...
# 34862      -0.175495    -0.326858    -0.234681     -0.048355        1.0
# 34863       0.975334    -0.326858    -0.234681     -0.048355        3.0
# 34864       0.975334    -0.326858    -0.234681     -0.048355        1.0
# 34865      -0.559105    -0.326858    -0.234681      1.092439        3.0
# 34866       1.742553     3.933366    -0.234681      1.092439        3.0
#
#        education  marital-status  occupation  relationship  race  sex  \
# id
# 27867       12.0             0.0         9.0           1.0   4.0  1.0
# 27868       11.0             2.0         2.0           0.0   4.0  1.0
# 27869        9.0             2.0         9.0           0.0   1.0  1.0
# 27870       15.0             4.0         7.0           3.0   1.0  0.0
# 27871        7.0             2.0        10.0           0.0   4.0  1.0
# ...          ...             ...         ...           ...   ...  ...
# 34862       15.0             4.0        10.0           1.0   2.0  1.0
# 34863        9.0             4.0        11.0           3.0   4.0  1.0
# 34864        9.0             2.0         9.0           0.0   4.0  1.0
# 34865       11.0             2.0        13.0           0.0   4.0  1.0
# 34866       14.0             4.0         9.0           1.0   4.0  0.0
#
#        native-country-code  native-country  prediction
# id
# 27867                  0.0             1.0         1.0
# 27868                 36.0            38.0         0.0
# 27869                  1.0             2.0         1.0
# 27870                 39.0            34.0         0.0
# 27871                 36.0            38.0         1.0
# ...                    ...             ...         ...
# 34862                 36.0            38.0         0.0
# 34863                  5.0            10.0         0.0
# 34864                 23.0            25.0         1.0
# 34865                 36.0            38.0         1.0
# 34866                 36.0            38.0         1.0
#
# [7000 rows x 18 columns]

# %%
data_train['prediction'] = model.predict(data_train.drop(['label'], axis='columns'))
data_train
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 8616                 1.074396      1.285441   0.071689  0.783535
# 21982               -1.534570     -1.103815   0.871141 -0.414340
# 11191               -0.952128      1.541907  -1.527215  0.499810
# 22229               -0.698142      1.208222   0.071689 -0.683323
# 20732               -0.502967     -1.318003   0.871141 -0.277714
# ...                       ...           ...        ...       ...
# 21575                0.248551      1.336455  -1.527215 -0.405358
# 5390                -0.297652      0.539104   0.871141  1.368795
# 860                  0.494586     -1.309268   0.871141 -1.431674
# 15795               -1.138869      0.965033  -1.527215  0.835243
# 23654               -0.053051     -0.799480   1.670593 -0.114799
#
#        education-num  capitalgain  capitalloss  hoursperweek  workclass  \
# id
# 8616        0.975334    -0.326858    -0.234681      1.092439        4.0
# 21982       2.126163    -0.326858     2.877363     -0.048355        1.0
# 11191      -0.559105    -0.326858    -0.234681     -1.189149        3.0
# 22229      -0.559105    -0.326858    -0.234681     -0.048355        3.0
# 20732       0.975334    -0.326858    -0.234681      1.092439        3.0
# ...              ...          ...          ...           ...        ...
# 21575       0.591724    -0.326858    -0.234681     -0.048355        3.0
# 5390       -3.627983    -0.326858    -0.234681     -0.048355        3.0
# 860        -0.175495    -0.326858    -0.234681     -0.048355        3.0
# 15795      -0.175495    -0.326858    -0.234681     -0.048355        6.0
# 23654       1.358944    -0.326858    -0.234681      1.092439        3.0
#
#        education  marital-status  occupation  relationship  race  sex  \
# id
# 8616         9.0             2.0         3.0           0.0   4.0  1.0
# 21982       10.0             2.0         9.0           0.0   4.0  1.0
# 11191       11.0             4.0         7.0           1.0   4.0  0.0
# 22229       11.0             0.0         6.0           2.0   2.0  1.0
# 20732        9.0             2.0        11.0           0.0   4.0  1.0
# ...          ...             ...         ...           ...   ...  ...
# 21575        7.0             4.0        11.0           1.0   4.0  1.0
# 5390        13.0             2.0         7.0           0.0   4.0  1.0
# 860         15.0             2.0         0.0           0.0   4.0  1.0
# 15795       15.0             4.0         6.0           3.0   4.0  0.0
# 23654       12.0             2.0         3.0           0.0   4.0  1.0
#
#        native-country-code  native-country  label  prediction
# id
# 8616                  36.0            38.0    1.0         1.0
# 21982                 36.0            38.0    1.0         1.0
# 11191                 36.0            38.0    0.0         0.0
# 22229                 36.0            38.0    0.0         0.0
# 20732                 36.0            38.0    1.0         1.0
# ...                    ...             ...    ...         ...
# 21575                 36.0            38.0    0.0         0.0
# 5390                  23.0            25.0    0.0         0.0
# 860                   36.0            38.0    1.0         1.0
# 15795                 36.0            38.0    0.0         0.0
# 23654                 36.0            38.0    1.0         1.0
#
# [20900 rows x 19 columns]

# %%
data_train.to_csv('./results/predictions.train.csv')
data_test.to_csv('./results/predictions.test.csv')

# %% [markdown]
# # Instructions
# - Use `sklearn.metrics.confusion_matrix` to calculate the confusion matrix

# %%
confusion_matrix_from_sklearn = sklearn.metrics.confusion_matrix(
    y_true = data_train['label'],
    y_pred = data_train['prediction'],
)
confusion_matrix_from_sklearn
# Out:
# array([[8892, 3243],
#        [1631, 7134]])

# %% [markdown]
# # Instructions
#
# - Use `sklearn.metrics.classification_report` to print the classification report
# - Now, **manually fill** the following metrics `y=1` and put them in a Python dictionary
# - The expected output should look like:
#
# ```
# scores = {
#      'true_positive': 45,
#      'true_negative': 144,
#      'false_negative': 29,
#      'false_positive': 32,
#      'accuracy': 0.756,
#      'precision': 0.584416,
#      'recall': 0.608108,
#      'support': 74,
#      'f1-score': 0.596026
# }
# ```
# - Use `json.dump` to save the output to  `./results/scores.test.json`

# %%
pandas.DataFrame(sklearn.metrics.classification_report(
    y_true = data_train['label'],
    y_pred = data_train['prediction'],
    digits = 4,
    output_dict = True,
))
# Out:
#                     0.0          1.0  accuracy     macro avg  weighted avg
# precision      0.845006     0.687482  0.766794      0.766244      0.778944
# recall         0.732756     0.813919  0.766794      0.773338      0.766794
# f1-score       0.784888     0.745377  0.766794      0.765132      0.768318
# support    12135.000000  8765.000000  0.766794  20900.000000  20900.000000

# %%
scores = {
     'true_positive': 45,
     'true_negative': 144,
     'false_negative': 29,
     'false_positive': 32,
     'accuracy': 0.756,
     'precision': 0.584416,
     'recall': 0.608108,
     'support': 74,
     'f1-score': 0.596026
}

# %%
with open('./results/scores.test.json', 'w') as f:
    json.dump(scores, f, indent=4)
