# %%
import pandas
import seaborn
import numpy
import sklearn.preprocessing
import sklearn.impute

# %matplotlib inline

# %% [markdown]
# # Instructions
#
# - Read both training and test data from CSV files
# - Then, identify which columns are numerical and which columns are categorical
# - Assess whether the data is balance or imbalance

# %%
data_train = pandas.read_csv('../data/high_salary.train.csv').set_index('id')
data_train
# Out:
#        social-security-number  house-number  age-group     workclass  \
# id
# 8616              830617145.0        8732.0        2.0  self-emp-inc
# 21982             151595184.0        1894.0        3.0     local-gov
# 11191             303184281.0        9466.0        0.0       private
# 22229             369287837.0        8511.0        2.0       private
# 20732             420084973.0        1281.0        3.0       private
# ...                       ...           ...        ...           ...
# 21575             615678823.0        8878.0        0.0       private
# 5390              473521238.0        6596.0        3.0       private
# 860               679713121.0        1306.0        3.0       private
# 15795             254582054.0        7815.0        0.0     state-gov
# 23654             537182363.0        2765.0        4.0       private
#
#          fnlwgt     education  education-num      marital-status  \
# id
# 8616   270079.0     bachelors           13.0  married-civ-spouse
# 21982  146325.0     doctorate           16.0  married-civ-spouse
# 11191  240767.0       hs-grad            9.0       never-married
# 22229  118536.0       hs-grad            9.0            divorced
# 20732  160440.0     bachelors           13.0  married-civ-spouse
# ...         ...           ...            ...                 ...
# 21575  147253.0    assoc-acdm           12.0       never-married
# 5390   330543.0     preschool            1.0  married-civ-spouse
# 860     41223.0  some-college           10.0  married-civ-spouse
# 15795  275421.0  some-college           10.0       never-married
# 23654  177271.0       masters           14.0  married-civ-spouse
#
#               occupation    relationship   race     sex  capitalgain  \
# id
# 8616     exec-managerial         husband  white    male          0.0
# 21982     prof-specialty         husband  white    male          0.0
# 11191      other-service   not-in-family  white  female          0.0
# 22229  machine-op-inspct  other-relative  black    male          0.0
# 20732              sales         husband  white    male          0.0
# ...                  ...             ...    ...     ...          ...
# 21575              sales   not-in-family  white    male          0.0
# 5390       other-service         husband  white    male          0.0
# 860         adm-clerical         husband  white    male          0.0
# 15795  machine-op-inspct       own-child  white  female          0.0
# 23654    exec-managerial         husband  white    male          0.0
#
#        capitalloss  hoursperweek native-country-code native-country  label
# id
# 8616           0.0           3.0                 USA  united-states    1.0
# 21982          2.0           2.0                 USA  united-states    1.0
# 11191          0.0           1.0                 USA  united-states    0.0
# 22229          0.0           2.0                 USA  united-states    0.0
# 20732          0.0           3.0                 USA  united-states    1.0
# ...            ...           ...                 ...            ...    ...
# 21575          0.0           2.0                 USA  united-states    0.0
# 5390           0.0           2.0                 MEX         mexico    0.0
# 860            0.0           2.0                 USA  united-states    1.0
# 15795          0.0           2.0                 USA  united-states    0.0
# 23654          0.0           3.0                 USA  united-states    1.0
#
# [20900 rows x 18 columns]

# %%
data_test = pandas.read_csv('../data/high_salary.test_features.csv').set_index('id')
data_test
# Out:
#        social-security-number  house-number  age-group         workclass  \
# id
# 27867             532734813.0        4238.0        NaN           private
# 27868             636521681.0        1679.0        1.0  self-emp-not-inc
# 27869             864336060.0        7623.0        2.0           private
# 27870             584984085.0        7483.0        0.0      self-emp-inc
# 27871             924906706.0        3661.0        1.0         local-gov
# ...                       ...           ...        ...               ...
# 34862             292322045.0        4914.0        1.0         local-gov
# 34863             475380257.0        6586.0        2.0           private
# 34864             463791400.0         387.0        1.0         local-gov
# 34865             113179248.0        3779.0        3.0           private
# 34866             787584207.0         730.0        2.0           private
#
#          fnlwgt     education  education-num      marital-status  \
# id
# 27867  214541.0       masters           14.0            divorced
# 27868   62932.0       hs-grad            9.0  married-civ-spouse
# 27869  269168.0     bachelors           13.0  married-civ-spouse
# 27870  148955.0  some-college           10.0       never-married
# 27871  182570.0    assoc-acdm           12.0  married-civ-spouse
# ...         ...           ...            ...                 ...
# 34862  275369.0  some-college           10.0       never-married
# 34863  230467.0     bachelors           13.0       never-married
# 34864  429897.0     bachelors           13.0  married-civ-spouse
# 34865  249072.0       hs-grad            9.0  married-civ-spouse
# 34866  105794.0   prof-school           15.0       never-married
#
#              occupation   relationship                race     sex  \
# id
# 27867    prof-specialty  not-in-family               white    male
# 27868      craft-repair        husband               white    male
# 27869    prof-specialty        husband  asian-pac-islander    male
# 27870     other-service      own-child  asian-pac-islander  female
# 27871   protective-serv        husband               white    male
# ...                 ...            ...                 ...     ...
# 34862   protective-serv  not-in-family               black    male
# 34863             sales      own-child               white    male
# 34864    prof-specialty        husband               white    male
# 34865  transport-moving        husband               white    male
# 34866    prof-specialty  not-in-family               white  female
#
#        capitalgain  capitalloss  hoursperweek native-country-code  \
# id
# 27867          0.0          0.0           2.0                 CAN
# 27868          0.0          0.0           2.0                 USA
# 27869          0.0          0.0           2.0                 CHN
# 27870          0.0          0.0           1.0                 ZAF
# 27871          0.0          0.0           2.0                 USA
# ...            ...          ...           ...                 ...
# 34862          0.0          0.0           2.0                 USA
# 34863          0.0          0.0           2.0                 DUE
# 34864          0.0          0.0           2.0                 MEX
# 34865          0.0          0.0           3.0                 USA
# 34866          4.0          0.0           3.0                 USA
#
#       native-country
# id
# 27867         canada
# 27868  united-states
# 27869          china
# 27870          south
# 27871  united-states
# ...              ...
# 34862  united-states
# 34863        germany
# 34864         mexico
# 34865  united-states
# 34866  united-states
#
# [7000 rows x 17 columns]

# %% [markdown]
# mean_social_security_number = data_test['social-security-number'].mean()
#
# mean_df = data_test.fillna({'social-security-number': mean_social_security_number,})
# mean_df

# %% [markdown]
# mean_df.isna().sum(axis='index')

# %%
data_train.dtypes
# Out:
# social-security-number    float64
# house-number              float64
# age-group                 float64
# workclass                  object
# fnlwgt                    float64
# education                  object
# education-num             float64
# marital-status             object
# occupation                 object
# relationship               object
# race                       object
# sex                        object
# capitalgain               float64
# capitalloss               float64
# hoursperweek              float64
# native-country-code        object
# native-country             object
# label                     float64
# dtype: object

# %%
categorical_features = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country-code',
    'native-country'
]

for feature in categorical_features:
    possible_values = data_train[feature].unique()
    print(feature, possible_values)
# Out:
# workclass ['self-emp-inc' 'local-gov' 'private' 'state-gov' 'self-emp-not-inc' nan
#  'federal-gov' 'without-pay' 'never-worked']
# education ['bachelors' 'doctorate' 'hs-grad' '10th' 'some-college' 'masters'
#  'prof-school' '5th-6th' '7th-8th' 'assoc-acdm' '12th' 'preschool'
#  'assoc-voc' '9th' '11th' '1st-4th' nan]
# marital-status ['married-civ-spouse' 'never-married' 'divorced' 'widowed' 'separated'
#  'married-spouse-absent' 'married-af-spouse' nan]
# occupation ['exec-managerial' 'prof-specialty' 'other-service' 'machine-op-inspct'
#  'sales' 'handlers-cleaners' 'craft-repair' 'adm-clerical' 'tech-support'
#  nan 'farming-fishing' 'transport-moving' 'priv-house-serv'
#  'protective-serv' 'armed-forces']
# relationship ['husband' 'not-in-family' 'other-relative' 'unmarried' 'own-child' 'wife'
#  nan]
# race ['white' 'black' 'amer-indian-eskimo' 'other' 'asian-pac-islander' nan]
# sex ['male' 'female' nan]
# native-country-code ['USA' 'ECU' 'FRA' 'MEX' 'CAN' 'SLV' 'ZAF' 'LAO' 'PER' 'PRT' 'DUE' nan
#  'CHN' 'PRI' 'JPN' 'JAM' 'HTI' 'DOM' 'ITA' 'COL' 'PHL' 'CUB' 'TWN' 'IND'
#  'NIC' 'VNM' 'KHM' 'IRN' 'GTM' 'GBR' 'HKG' 'HUN' 'HND' 'THA' 'POL' 'IRL'
#  'UMI' 'GRC' 'YUG' 'TTO' 'NLD']
# native-country ['united-states' 'ecuador' 'france' 'mexico' 'canada' 'el-salvador'
#  'south' 'laos' 'peru' 'portugal' 'germany' nan 'china' 'puerto-rico'
#  'japan' 'jamaica' 'haiti' 'dominican-republic' 'italy' 'columbia'
#  'philippines' 'cuba' 'taiwan' 'india' 'nicaragua' 'vietnam' 'cambodia'
#  'iran' 'guatemala' 'england' 'hong' 'hungary' 'honduras' 'thailand'
#  'poland' 'scotland' 'ireland' 'outlying-us(guam-usvi-etc)' 'greece'
#  'yugoslavia' 'trinadad&tobago' 'holand-netherlands']

# %%
numerical_features = [
    'social-security-number',
    'house-number',
    'age-group',
    'fnlwgt',
    'education-num',
    'capitalgain',
    'capitalloss',
    'hoursperweek',
    
]

data_train[numerical_features].describe()
# Out:
#        social-security-number  house-number     age-group        fnlwgt  \
# count            2.088600e+04   20873.00000  20887.000000  2.087700e+04
# mean             5.509897e+08    5053.09553      1.910327  1.891310e+05
# std              2.603583e+08    2863.89731      1.251276  1.033706e+05
# min              1.000659e+08     101.00000      0.000000  1.376900e+04
# 25%              3.209004e+08    2602.00000      1.000000  1.178490e+05
# 50%              5.521493e+08    5011.00000      2.000000  1.779450e+05
# 75%              7.770986e+08    7554.00000      3.000000  2.367690e+05
# max              9.999588e+08    9998.00000      4.000000  1.226583e+06
#
#        education-num   capitalgain   capitalloss  hoursperweek
# count   20886.000000  20877.000000  20879.000000  20879.000000
# mean       10.457483      0.306893      0.150821      2.042387
# std         2.607752      0.939457      0.643003      0.877044
# min         1.000000      0.000000      0.000000      0.000000
# 25%         9.000000      0.000000      0.000000      2.000000
# 50%        10.000000      0.000000      0.000000      2.000000
# 75%        13.000000      0.000000      0.000000      3.000000
# max        16.000000      4.000000      4.000000      4.000000

# %%
data_train['label'].value_counts()
# Out:
# label
# 0.0    12135
# 1.0     8765
# Name: count, dtype: int64

# %% [markdown]
# data_test['label'].value_counts()

# %% [markdown]
# # Instructions
# - Investigate whether the dataset contains any missing data

# %%
data_train.isna().sum(axis='index')
# Out:
# social-security-number      14
# house-number                27
# age-group                   13
# workclass                 1057
# fnlwgt                      23
# education                   20
# education-num               14
# marital-status              23
# occupation                1054
# relationship                21
# race                        22
# sex                         22
# capitalgain                 23
# capitalloss                 21
# hoursperweek                21
# native-country-code        399
# native-country             398
# label                        0
# dtype: int64

# %%
data_test.isna().sum(axis='index')
# Out:
# social-security-number      6
# house-number                7
# age-group                   9
# workclass                 349
# fnlwgt                      5
# education                  11
# education-num               3
# marital-status              6
# occupation                349
# relationship               13
# race                        2
# sex                        11
# capitalgain                 7
# capitalloss                12
# hoursperweek                6
# native-country-code       130
# native-country            123
# dtype: int64

# %% [markdown]
# # Instructions
# - Now, preprocess the data before model training
# - Create 3 `pandas.DataFrames`
#     - `pandas.DataFrame` of only ordinal features encoded using `sklearn.preprocessing.OrdinalEncoder`
#     - `pandas.DataFrame` of only numerical features. Also, apply `sklearn.preprocessing.StandardScaler`.
#     - `pandas.DataFrame` of labels encoded using `sklearn.preprocessing.OrdinalEncoder`
#         - Map {`no`, `yes`} to {0, 1} respectively
# - Use `sklearn.impute.SimpleImputer` to handle missing values in each `pandas.DataFrame`
# - Then, combine the 3 `pandas.DataFrame` to obtain the fully processed training and test data
#     - Hint: use `.join`

# %% [markdown]
# ## For categorical features
# - Define a subset of categorical features
# - Use `sklearn.impute.SimpleImputer` to handle missing values by filling in with a majority category from the **training data**
# - Then, Use `sklearn.preprocessing.OrdinalEncoder` to create an ordinal encoder, then fit using the training data
# - Create a new `pandas.DataFrame` of only ordinally encoded features for both training and test data

# %%
categorical_features = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country-code',
    'native-country'
]

# %%
data_train_categorical_features = data_train[categorical_features]
data_train_categorical_features
# Out:
#           workclass     education      marital-status         occupation  \
# id
# 8616   self-emp-inc     bachelors  married-civ-spouse    exec-managerial
# 21982     local-gov     doctorate  married-civ-spouse     prof-specialty
# 11191       private       hs-grad       never-married      other-service
# 22229       private       hs-grad            divorced  machine-op-inspct
# 20732       private     bachelors  married-civ-spouse              sales
# ...             ...           ...                 ...                ...
# 21575       private    assoc-acdm       never-married              sales
# 5390        private     preschool  married-civ-spouse      other-service
# 860         private  some-college  married-civ-spouse       adm-clerical
# 15795     state-gov  some-college       never-married  machine-op-inspct
# 23654       private       masters  married-civ-spouse    exec-managerial
#
#          relationship   race     sex native-country-code native-country
# id
# 8616          husband  white    male                 USA  united-states
# 21982         husband  white    male                 USA  united-states
# 11191   not-in-family  white  female                 USA  united-states
# 22229  other-relative  black    male                 USA  united-states
# 20732         husband  white    male                 USA  united-states
# ...               ...    ...     ...                 ...            ...
# 21575   not-in-family  white    male                 USA  united-states
# 5390          husband  white    male                 MEX         mexico
# 860           husband  white    male                 USA  united-states
# 15795       own-child  white  female                 USA  united-states
# 23654         husband  white    male                 USA  united-states
#
# [20900 rows x 9 columns]

# %%
data_test_categorical_features = data_test[categorical_features]
data_test_categorical_features
# Out:
#               workclass     education      marital-status        occupation  \
# id
# 27867           private       masters            divorced    prof-specialty
# 27868  self-emp-not-inc       hs-grad  married-civ-spouse      craft-repair
# 27869           private     bachelors  married-civ-spouse    prof-specialty
# 27870      self-emp-inc  some-college       never-married     other-service
# 27871         local-gov    assoc-acdm  married-civ-spouse   protective-serv
# ...                 ...           ...                 ...               ...
# 34862         local-gov  some-college       never-married   protective-serv
# 34863           private     bachelors       never-married             sales
# 34864         local-gov     bachelors  married-civ-spouse    prof-specialty
# 34865           private       hs-grad  married-civ-spouse  transport-moving
# 34866           private   prof-school       never-married    prof-specialty
#
#         relationship                race     sex native-country-code  \
# id
# 27867  not-in-family               white    male                 CAN
# 27868        husband               white    male                 USA
# 27869        husband  asian-pac-islander    male                 CHN
# 27870      own-child  asian-pac-islander  female                 ZAF
# 27871        husband               white    male                 USA
# ...              ...                 ...     ...                 ...
# 34862  not-in-family               black    male                 USA
# 34863      own-child               white    male                 DUE
# 34864        husband               white    male                 MEX
# 34865        husband               white    male                 USA
# 34866  not-in-family               white  female                 USA
#
#       native-country
# id
# 27867         canada
# 27868  united-states
# 27869          china
# 27870          south
# 27871  united-states
# ...              ...
# 34862  united-states
# 34863        germany
# 34864         mexico
# 34865  united-states
# 34866  united-states
#
# [7000 rows x 9 columns]

# %%
categorical_imputer = sklearn.impute.SimpleImputer(strategy='most_frequent')
categorical_imputer
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
categorical_imputer.fit(data_train_categorical_features)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
data_train_categorical_features = pandas.DataFrame(
    data = categorical_imputer.transform(data_train_categorical_features),
    columns = categorical_imputer.get_feature_names_out(),
    index = data_train_categorical_features.index
)
data_train_categorical_features
# Out:
#           workclass     education      marital-status         occupation  \
# id
# 8616   self-emp-inc     bachelors  married-civ-spouse    exec-managerial
# 21982     local-gov     doctorate  married-civ-spouse     prof-specialty
# 11191       private       hs-grad       never-married      other-service
# 22229       private       hs-grad            divorced  machine-op-inspct
# 20732       private     bachelors  married-civ-spouse              sales
# ...             ...           ...                 ...                ...
# 21575       private    assoc-acdm       never-married              sales
# 5390        private     preschool  married-civ-spouse      other-service
# 860         private  some-college  married-civ-spouse       adm-clerical
# 15795     state-gov  some-college       never-married  machine-op-inspct
# 23654       private       masters  married-civ-spouse    exec-managerial
#
#          relationship   race     sex native-country-code native-country
# id
# 8616          husband  white    male                 USA  united-states
# 21982         husband  white    male                 USA  united-states
# 11191   not-in-family  white  female                 USA  united-states
# 22229  other-relative  black    male                 USA  united-states
# 20732         husband  white    male                 USA  united-states
# ...               ...    ...     ...                 ...            ...
# 21575   not-in-family  white    male                 USA  united-states
# 5390          husband  white    male                 MEX         mexico
# 860           husband  white    male                 USA  united-states
# 15795       own-child  white  female                 USA  united-states
# 23654         husband  white    male                 USA  united-states
#
# [20900 rows x 9 columns]

# %%
data_test_categorical_features = pandas.DataFrame(
    data = categorical_imputer.transform(data_test_categorical_features),
    columns = categorical_imputer.get_feature_names_out(),
    index = data_test_categorical_features.index
)
data_test_categorical_features
# Out:
#               workclass     education      marital-status        occupation  \
# id
# 27867           private       masters            divorced    prof-specialty
# 27868  self-emp-not-inc       hs-grad  married-civ-spouse      craft-repair
# 27869           private     bachelors  married-civ-spouse    prof-specialty
# 27870      self-emp-inc  some-college       never-married     other-service
# 27871         local-gov    assoc-acdm  married-civ-spouse   protective-serv
# ...                 ...           ...                 ...               ...
# 34862         local-gov  some-college       never-married   protective-serv
# 34863           private     bachelors       never-married             sales
# 34864         local-gov     bachelors  married-civ-spouse    prof-specialty
# 34865           private       hs-grad  married-civ-spouse  transport-moving
# 34866           private   prof-school       never-married    prof-specialty
#
#         relationship                race     sex native-country-code  \
# id
# 27867  not-in-family               white    male                 CAN
# 27868        husband               white    male                 USA
# 27869        husband  asian-pac-islander    male                 CHN
# 27870      own-child  asian-pac-islander  female                 ZAF
# 27871        husband               white    male                 USA
# ...              ...                 ...     ...                 ...
# 34862  not-in-family               black    male                 USA
# 34863      own-child               white    male                 DUE
# 34864        husband               white    male                 MEX
# 34865        husband               white    male                 USA
# 34866  not-in-family               white  female                 USA
#
#       native-country
# id
# 27867         canada
# 27868  united-states
# 27869          china
# 27870          south
# 27871  united-states
# ...              ...
# 34862  united-states
# 34863        germany
# 34864         mexico
# 34865  united-states
# 34866  united-states
#
# [7000 rows x 9 columns]

# %%
data_train_categorical_features.isna().sum(axis='index')
# Out:
# workclass              0
# education              0
# marital-status         0
# occupation             0
# relationship           0
# race                   0
# sex                    0
# native-country-code    0
# native-country         0
# dtype: int64

# %%
data_test_categorical_features.isna().sum(axis='index')
# Out:
# workclass              0
# education              0
# marital-status         0
# occupation             0
# relationship           0
# race                   0
# sex                    0
# native-country-code    0
# native-country         0
# dtype: int64

# %%
ordinal_encoder = sklearn.preprocessing.OrdinalEncoder()
ordinal_encoder
# Out:
# OrdinalEncoder()

# %%
ordinal_encoder.fit(data_train_categorical_features)
# Out:
# OrdinalEncoder()

# %%
ordinal_encoder.categories_
# Out:
# [array(['federal-gov', 'local-gov', 'never-worked', 'private',
#         'self-emp-inc', 'self-emp-not-inc', 'state-gov', 'without-pay'],
#        dtype=object),
#  array(['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th', '9th',
#         'assoc-acdm', 'assoc-voc', 'bachelors', 'doctorate', 'hs-grad',
#         'masters', 'preschool', 'prof-school', 'some-college'],
#        dtype=object),
#  array(['divorced', 'married-af-spouse', 'married-civ-spouse',
#         'married-spouse-absent', 'never-married', 'separated', 'widowed'],
#        dtype=object),
#  array(['adm-clerical', 'armed-forces', 'craft-repair', 'exec-managerial',
#         'farming-fishing', 'handlers-cleaners', 'machine-op-inspct',
#         'other-service', 'priv-house-serv', 'prof-specialty',
#         'protective-serv', 'sales', 'tech-support', 'transport-moving'],
#        dtype=object),
#  array(['husband', 'not-in-family', 'other-relative', 'own-child',
#         'unmarried', 'wife'], dtype=object),
#  array(['amer-indian-eskimo', 'asian-pac-islander', 'black', 'other',
#         'white'], dtype=object),
#  array(['female', 'male'], dtype=object),
#  array(['CAN', 'CHN', 'COL', 'CUB', 'DOM', 'DUE', 'ECU', 'FRA', 'GBR',
#         'GRC', 'GTM', 'HKG', 'HND', 'HTI', 'HUN', 'IND', 'IRL', 'IRN',
#         'ITA', 'JAM', 'JPN', 'KHM', 'LAO', 'MEX', 'NIC', 'NLD', 'PER',
#         'PHL', 'POL', 'PRI', 'PRT', 'SLV', 'THA', 'TTO', 'TWN', 'UMI',
#         'USA', 'VNM', 'YUG', 'ZAF'], dtype=object),
#  array(['cambodia', 'canada', 'china', 'columbia', 'cuba',
#         'dominican-republic', 'ecuador', 'el-salvador', 'england',
#         'france', 'germany', 'greece', 'guatemala', 'haiti',
#         'holand-netherlands', 'honduras', 'hong', 'hungary', 'india',
#         'iran', 'ireland', 'italy', 'jamaica', 'japan', 'laos', 'mexico',
#         'nicaragua', 'outlying-us(guam-usvi-etc)', 'peru', 'philippines',
#         'poland', 'portugal', 'puerto-rico', 'scotland', 'south', 'taiwan',
#         'thailand', 'trinadad&tobago', 'united-states', 'vietnam',
#         'yugoslavia'], dtype=object)]

# %%
data_train_categorical_features = pandas.DataFrame(
    data = ordinal_encoder.transform(data_train_categorical_features),
    columns = ordinal_encoder.get_feature_names_out(),
    index = data_train_categorical_features.index
)
data_train_categorical_features
# Out:
#        workclass  education  marital-status  occupation  relationship  race  \
# id
# 8616         4.0        9.0             2.0         3.0           0.0   4.0
# 21982        1.0       10.0             2.0         9.0           0.0   4.0
# 11191        3.0       11.0             4.0         7.0           1.0   4.0
# 22229        3.0       11.0             0.0         6.0           2.0   2.0
# 20732        3.0        9.0             2.0        11.0           0.0   4.0
# ...          ...        ...             ...         ...           ...   ...
# 21575        3.0        7.0             4.0        11.0           1.0   4.0
# 5390         3.0       13.0             2.0         7.0           0.0   4.0
# 860          3.0       15.0             2.0         0.0           0.0   4.0
# 15795        6.0       15.0             4.0         6.0           3.0   4.0
# 23654        3.0       12.0             2.0         3.0           0.0   4.0
#
#        sex  native-country-code  native-country
# id
# 8616   1.0                 36.0            38.0
# 21982  1.0                 36.0            38.0
# 11191  0.0                 36.0            38.0
# 22229  1.0                 36.0            38.0
# 20732  1.0                 36.0            38.0
# ...    ...                  ...             ...
# 21575  1.0                 36.0            38.0
# 5390   1.0                 23.0            25.0
# 860    1.0                 36.0            38.0
# 15795  0.0                 36.0            38.0
# 23654  1.0                 36.0            38.0
#
# [20900 rows x 9 columns]

# %%
data_test_categorical_features = pandas.DataFrame(
    data = ordinal_encoder.transform(data_test_categorical_features),
    columns = ordinal_encoder.get_feature_names_out(),
    index = data_test_categorical_features.index
)
data_test_categorical_features
# Out:
#        workclass  education  marital-status  occupation  relationship  race  \
# id
# 27867        3.0       12.0             0.0         9.0           1.0   4.0
# 27868        5.0       11.0             2.0         2.0           0.0   4.0
# 27869        3.0        9.0             2.0         9.0           0.0   1.0
# 27870        4.0       15.0             4.0         7.0           3.0   1.0
# 27871        1.0        7.0             2.0        10.0           0.0   4.0
# ...          ...        ...             ...         ...           ...   ...
# 34862        1.0       15.0             4.0        10.0           1.0   2.0
# 34863        3.0        9.0             4.0        11.0           3.0   4.0
# 34864        1.0        9.0             2.0         9.0           0.0   4.0
# 34865        3.0       11.0             2.0        13.0           0.0   4.0
# 34866        3.0       14.0             4.0         9.0           1.0   4.0
#
#        sex  native-country-code  native-country
# id
# 27867  1.0                  0.0             1.0
# 27868  1.0                 36.0            38.0
# 27869  1.0                  1.0             2.0
# 27870  0.0                 39.0            34.0
# 27871  1.0                 36.0            38.0
# ...    ...                  ...             ...
# 34862  1.0                 36.0            38.0
# 34863  1.0                  5.0            10.0
# 34864  1.0                 23.0            25.0
# 34865  1.0                 36.0            38.0
# 34866  0.0                 36.0            38.0
#
# [7000 rows x 9 columns]

# %% [markdown]
# ## For numerical features
# - Define and select a subset of numerical
# -  features for training and test data
# - Use `sklearn.impute.SimpleImputer` to handle missing values by filling in with a mean from the training data
# - Then, standardize the numerical data
#     - Use `seaborn.violinplot` to show a distribution of the numerical data before standardization.
#     - Apply `sklearn.preprocessing.StandardScaler` to create a standard scaler, then fit using the training data
#     - Use `seaborn.violinplot` again to show that the numerical data is properly standardized.
# - Create a new `pandas.DataFrame` of only numerically encoded features for both training and test data

# %%
numerical_features = [
    'social-security-number',
    'house-number',
    'age-group',
    'fnlwgt',
    'education-num',
    'capitalgain',
    'capitalloss',
    'hoursperweek',
]

# %%
data_train_numerical_features = data_train[numerical_features]
data_train_numerical_features
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 8616              830617145.0        8732.0        2.0  270079.0
# 21982             151595184.0        1894.0        3.0  146325.0
# 11191             303184281.0        9466.0        0.0  240767.0
# 22229             369287837.0        8511.0        2.0  118536.0
# 20732             420084973.0        1281.0        3.0  160440.0
# ...                       ...           ...        ...       ...
# 21575             615678823.0        8878.0        0.0  147253.0
# 5390              473521238.0        6596.0        3.0  330543.0
# 860               679713121.0        1306.0        3.0   41223.0
# 15795             254582054.0        7815.0        0.0  275421.0
# 23654             537182363.0        2765.0        4.0  177271.0
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 8616            13.0          0.0          0.0           3.0
# 21982           16.0          0.0          2.0           2.0
# 11191            9.0          0.0          0.0           1.0
# 22229            9.0          0.0          0.0           2.0
# 20732           13.0          0.0          0.0           3.0
# ...              ...          ...          ...           ...
# 21575           12.0          0.0          0.0           2.0
# 5390             1.0          0.0          0.0           2.0
# 860             10.0          0.0          0.0           2.0
# 15795           10.0          0.0          0.0           2.0
# 23654           14.0          0.0          0.0           3.0
#
# [20900 rows x 8 columns]

# %%
data_test_numerical_features = data_test[numerical_features]
data_test_numerical_features
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 27867             532734813.0        4238.0        NaN  214541.0
# 27868             636521681.0        1679.0        1.0   62932.0
# 27869             864336060.0        7623.0        2.0  269168.0
# 27870             584984085.0        7483.0        0.0  148955.0
# 27871             924906706.0        3661.0        1.0  182570.0
# ...                       ...           ...        ...       ...
# 34862             292322045.0        4914.0        1.0  275369.0
# 34863             475380257.0        6586.0        2.0  230467.0
# 34864             463791400.0         387.0        1.0  429897.0
# 34865             113179248.0        3779.0        3.0  249072.0
# 34866             787584207.0         730.0        2.0  105794.0
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 27867           14.0          0.0          0.0           2.0
# 27868            9.0          0.0          0.0           2.0
# 27869           13.0          0.0          0.0           2.0
# 27870           10.0          0.0          0.0           1.0
# 27871           12.0          0.0          0.0           2.0
# ...              ...          ...          ...           ...
# 34862           10.0          0.0          0.0           2.0
# 34863           13.0          0.0          0.0           2.0
# 34864           13.0          0.0          0.0           2.0
# 34865            9.0          0.0          0.0           3.0
# 34866           15.0          4.0          0.0           3.0
#
# [7000 rows x 8 columns]

# %%
numerical_imputer = sklearn.impute.SimpleImputer(strategy = 'mean')
numerical_imputer
# Out:
# SimpleImputer()

# %%
numerical_imputer.fit(data_train_numerical_features)
# Out:
# SimpleImputer()

# %%
data_train_numerical_features = pandas.DataFrame(
    data = numerical_imputer.transform(data_train_numerical_features),
    columns = numerical_imputer.get_feature_names_out(),
    index = data_train_numerical_features.index
)
data_train_numerical_features
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 8616              830617145.0        8732.0        2.0  270079.0
# 21982             151595184.0        1894.0        3.0  146325.0
# 11191             303184281.0        9466.0        0.0  240767.0
# 22229             369287837.0        8511.0        2.0  118536.0
# 20732             420084973.0        1281.0        3.0  160440.0
# ...                       ...           ...        ...       ...
# 21575             615678823.0        8878.0        0.0  147253.0
# 5390              473521238.0        6596.0        3.0  330543.0
# 860               679713121.0        1306.0        3.0   41223.0
# 15795             254582054.0        7815.0        0.0  275421.0
# 23654             537182363.0        2765.0        4.0  177271.0
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 8616            13.0          0.0          0.0           3.0
# 21982           16.0          0.0          2.0           2.0
# 11191            9.0          0.0          0.0           1.0
# 22229            9.0          0.0          0.0           2.0
# 20732           13.0          0.0          0.0           3.0
# ...              ...          ...          ...           ...
# 21575           12.0          0.0          0.0           2.0
# 5390             1.0          0.0          0.0           2.0
# 860             10.0          0.0          0.0           2.0
# 15795           10.0          0.0          0.0           2.0
# 23654           14.0          0.0          0.0           3.0
#
# [20900 rows x 8 columns]

# %%
data_test_numerical_features = pandas.DataFrame(
    data = numerical_imputer.transform(data_test_numerical_features),
    columns = numerical_imputer.get_feature_names_out(),
    index = data_test_numerical_features.index
)
data_test_numerical_features
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 27867             532734813.0        4238.0   1.910327  214541.0
# 27868             636521681.0        1679.0   1.000000   62932.0
# 27869             864336060.0        7623.0   2.000000  269168.0
# 27870             584984085.0        7483.0   0.000000  148955.0
# 27871             924906706.0        3661.0   1.000000  182570.0
# ...                       ...           ...        ...       ...
# 34862             292322045.0        4914.0   1.000000  275369.0
# 34863             475380257.0        6586.0   2.000000  230467.0
# 34864             463791400.0         387.0   1.000000  429897.0
# 34865             113179248.0        3779.0   3.000000  249072.0
# 34866             787584207.0         730.0   2.000000  105794.0
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 27867           14.0          0.0          0.0           2.0
# 27868            9.0          0.0          0.0           2.0
# 27869           13.0          0.0          0.0           2.0
# 27870           10.0          0.0          0.0           1.0
# 27871           12.0          0.0          0.0           2.0
# ...              ...          ...          ...           ...
# 34862           10.0          0.0          0.0           2.0
# 34863           13.0          0.0          0.0           2.0
# 34864           13.0          0.0          0.0           2.0
# 34865            9.0          0.0          0.0           3.0
# 34866           15.0          4.0          0.0           3.0
#
# [7000 rows x 8 columns]

# %%
data_train_numerical_features.isna().sum(axis='index')
# Out:
# social-security-number    0
# house-number              0
# age-group                 0
# fnlwgt                    0
# education-num             0
# capitalgain               0
# capitalloss               0
# hoursperweek              0
# dtype: int64

# %%
data_test_numerical_features.isna().sum(axis='index')
# Out:
# social-security-number    0
# house-number              0
# age-group                 0
# fnlwgt                    0
# education-num             0
# capitalgain               0
# capitalloss               0
# hoursperweek              0
# dtype: int64

# %%
axes = seaborn.violinplot(
    data_train_numerical_features,
    order = numerical_features
)
axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# Out:
# /tmp/ipykernel_15347/1656974928.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# [Text(0, 0, 'social-security-number'),
#  Text(1, 0, 'house-number'),
#  Text(2, 0, 'age-group'),
#  Text(3, 0, 'fnlwgt'),
#  Text(4, 0, 'education-num'),
#  Text(5, 0, 'capitalgain'),
#  Text(6, 0, 'capitalloss'),
#  Text(7, 0, 'hoursperweek')]

# %%
axes = seaborn.violinplot(
    data_test_numerical_features,
    order = numerical_features
)
axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# Out:
# /tmp/ipykernel_15347/439515287.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# [Text(0, 0, 'social-security-number'),
#  Text(1, 0, 'house-number'),
#  Text(2, 0, 'age-group'),
#  Text(3, 0, 'fnlwgt'),
#  Text(4, 0, 'education-num'),
#  Text(5, 0, 'capitalgain'),
#  Text(6, 0, 'capitalloss'),
#  Text(7, 0, 'hoursperweek')]

# %%
standard_scaler = sklearn.preprocessing.StandardScaler()
standard_scaler
# Out:
# StandardScaler()

# %%
standard_scaler.fit(data_train_numerical_features)
# Out:
# StandardScaler()

# %%
data_train_numerical_features = pandas.DataFrame(
    data = standard_scaler.transform(data_train_numerical_features),
    columns = standard_scaler.get_feature_names_out(),
    index = data_train_numerical_features.index
)
data_train_numerical_features
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 8616                 1.074396      1.285441   0.071689  0.783535
# 21982               -1.534570     -1.103815   0.871141 -0.414340
# 11191               -0.952128      1.541907  -1.527215  0.499810
# 22229               -0.698142      1.208222   0.071689 -0.683323
# 20732               -0.502967     -1.318003   0.871141 -0.277714
# ...                       ...           ...        ...       ...
# 21575                0.248551      1.336455  -1.527215 -0.405358
# 5390                -0.297652      0.539104   0.871141  1.368795
# 860                  0.494586     -1.309268   0.871141 -1.431674
# 15795               -1.138869      0.965033  -1.527215  0.835243
# 23654               -0.053051     -0.799480   1.670593 -0.114799
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 8616        0.975334    -0.326858    -0.234681      1.092439
# 21982       2.126163    -0.326858     2.877363     -0.048355
# 11191      -0.559105    -0.326858    -0.234681     -1.189149
# 22229      -0.559105    -0.326858    -0.234681     -0.048355
# 20732       0.975334    -0.326858    -0.234681      1.092439
# ...              ...          ...          ...           ...
# 21575       0.591724    -0.326858    -0.234681     -0.048355
# 5390       -3.627983    -0.326858    -0.234681     -0.048355
# 860        -0.175495    -0.326858    -0.234681     -0.048355
# 15795      -0.175495    -0.326858    -0.234681     -0.048355
# 23654       1.358944    -0.326858    -0.234681      1.092439
#
# [20900 rows x 8 columns]

# %%
data_test_numerical_features = pandas.DataFrame(
    data = standard_scaler.transform(data_test_numerical_features),
    columns = standard_scaler.get_feature_names_out(),
    index = data_test_numerical_features.index
)
data_test_numerical_features
# Out:
#        social-security-number  house-number     age-group    fnlwgt  \
# id
# 27867               -0.070140     -0.284801 -1.775140e-16  0.245956
# 27868                0.328634     -1.178938 -7.277627e-01 -1.221542
# 27869                1.203952      0.897947  7.168925e-02  0.774717
# 27870                0.130615      0.849030 -1.527215e+00 -0.388883
# 27871                1.436679     -0.486410 -7.277627e-01 -0.063507
# ...                       ...           ...           ...       ...
# 34862               -0.993863     -0.048601 -7.277627e-01  0.834739
# 34863               -0.290510      0.535610  7.168925e-02  0.400111
# 34864               -0.335037     -1.630374 -7.277627e-01  2.330491
# 34865               -1.682173     -0.445180  8.711412e-01  0.580198
# 34866                0.909053     -1.510527  7.168925e-02 -0.806659
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 27867       1.358944    -0.326858    -0.234681     -0.048355
# 27868      -0.559105    -0.326858    -0.234681     -0.048355
# 27869       0.975334    -0.326858    -0.234681     -0.048355
# 27870      -0.175495    -0.326858    -0.234681     -1.189149
# 27871       0.591724    -0.326858    -0.234681     -0.048355
# ...              ...          ...          ...           ...
# 34862      -0.175495    -0.326858    -0.234681     -0.048355
# 34863       0.975334    -0.326858    -0.234681     -0.048355
# 34864       0.975334    -0.326858    -0.234681     -0.048355
# 34865      -0.559105    -0.326858    -0.234681      1.092439
# 34866       1.742553     3.933366    -0.234681      1.092439
#
# [7000 rows x 8 columns]

# %%
axes = seaborn.violinplot(
    data_train_numerical_features,
    order = numerical_features
)
axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# Out:
# /tmp/ipykernel_15347/1656974928.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# [Text(0, 0, 'social-security-number'),
#  Text(1, 0, 'house-number'),
#  Text(2, 0, 'age-group'),
#  Text(3, 0, 'fnlwgt'),
#  Text(4, 0, 'education-num'),
#  Text(5, 0, 'capitalgain'),
#  Text(6, 0, 'capitalloss'),
#  Text(7, 0, 'hoursperweek')]

# %%
axes = seaborn.violinplot(
    data_test_numerical_features,
    order = numerical_features
)
axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# Out:
# /tmp/ipykernel_15347/439515287.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# [Text(0, 0, 'social-security-number'),
#  Text(1, 0, 'house-number'),
#  Text(2, 0, 'age-group'),
#  Text(3, 0, 'fnlwgt'),
#  Text(4, 0, 'education-num'),
#  Text(5, 0, 'capitalgain'),
#  Text(6, 0, 'capitalloss'),
#  Text(7, 0, 'hoursperweek')]

# %% [markdown]
# ## For labels
# - Use `sklearn.preprocessing.OrdinalEncoder` to create an ordinal encoder, then fit using the training data
#     - Map {`no`, `yes`} to {0, 1} respectively
# - Create a new `pandas.DataFrame` of ordinally encoded labels for both training and test data

# %%
label_encoder = sklearn.preprocessing.OrdinalEncoder(categories = [['0.0', '1.0',]])
label_encoder
# Out:
# OrdinalEncoder(categories=[['0.0', '1.0']])

# %%
label_encoder.fit(data_train[['label']])
# Out:
# OrdinalEncoder(categories=[['0.0', '1.0']])

# %%
data_train_label = pandas.DataFrame(
    data = label_encoder.transform(data_train[['label']]),
    columns = ['label'],
    index = data_train.index
)
data_train_label
# Out:
#        label
# id
# 8616     1.0
# 21982    1.0
# 11191    0.0
# 22229    0.0
# 20732    1.0
# ...      ...
# 21575    0.0
# 5390     0.0
# 860      1.0
# 15795    0.0
# 23654    1.0
#
# [20900 rows x 1 columns]

# %% [markdown]
# data_test_label = pandas.DataFrame(
#     data = label_encoder.transform(data_test[['label']]),
#     columns = ['label'],
#     index = data_test.index
# )
# data_test_label

# %% [markdown]
# ## Reconstruction of data sets
# - Combine the 3 `pandas.DataFrame` to obtain the fully processed training and test data
#     - Hint: use `.join`

# %%
data_train = (
    data_train_categorical_features
    .join(data_train_numerical_features)
    .join(data_train[['label']])
)
data_train
# Out:
#        workclass  education  marital-status  occupation  relationship  race  \
# id
# 8616         4.0        9.0             2.0         3.0           0.0   4.0
# 21982        1.0       10.0             2.0         9.0           0.0   4.0
# 11191        3.0       11.0             4.0         7.0           1.0   4.0
# 22229        3.0       11.0             0.0         6.0           2.0   2.0
# 20732        3.0        9.0             2.0        11.0           0.0   4.0
# ...          ...        ...             ...         ...           ...   ...
# 21575        3.0        7.0             4.0        11.0           1.0   4.0
# 5390         3.0       13.0             2.0         7.0           0.0   4.0
# 860          3.0       15.0             2.0         0.0           0.0   4.0
# 15795        6.0       15.0             4.0         6.0           3.0   4.0
# 23654        3.0       12.0             2.0         3.0           0.0   4.0
#
#        sex  native-country-code  native-country  social-security-number  \
# id
# 8616   1.0                 36.0            38.0                1.074396
# 21982  1.0                 36.0            38.0               -1.534570
# 11191  0.0                 36.0            38.0               -0.952128
# 22229  1.0                 36.0            38.0               -0.698142
# 20732  1.0                 36.0            38.0               -0.502967
# ...    ...                  ...             ...                     ...
# 21575  1.0                 36.0            38.0                0.248551
# 5390   1.0                 23.0            25.0               -0.297652
# 860    1.0                 36.0            38.0                0.494586
# 15795  0.0                 36.0            38.0               -1.138869
# 23654  1.0                 36.0            38.0               -0.053051
#
#        house-number  age-group    fnlwgt  education-num  capitalgain  \
# id
# 8616       1.285441   0.071689  0.783535       0.975334    -0.326858
# 21982     -1.103815   0.871141 -0.414340       2.126163    -0.326858
# 11191      1.541907  -1.527215  0.499810      -0.559105    -0.326858
# 22229      1.208222   0.071689 -0.683323      -0.559105    -0.326858
# 20732     -1.318003   0.871141 -0.277714       0.975334    -0.326858
# ...             ...        ...       ...            ...          ...
# 21575      1.336455  -1.527215 -0.405358       0.591724    -0.326858
# 5390       0.539104   0.871141  1.368795      -3.627983    -0.326858
# 860       -1.309268   0.871141 -1.431674      -0.175495    -0.326858
# 15795      0.965033  -1.527215  0.835243      -0.175495    -0.326858
# 23654     -0.799480   1.670593 -0.114799       1.358944    -0.326858
#
#        capitalloss  hoursperweek  label
# id
# 8616     -0.234681      1.092439    1.0
# 21982     2.877363     -0.048355    1.0
# 11191    -0.234681     -1.189149    0.0
# 22229    -0.234681     -0.048355    0.0
# 20732    -0.234681      1.092439    1.0
# ...            ...           ...    ...
# 21575    -0.234681     -0.048355    0.0
# 5390     -0.234681     -0.048355    0.0
# 860      -0.234681     -0.048355    1.0
# 15795    -0.234681     -0.048355    0.0
# 23654    -0.234681      1.092439    1.0
#
# [20900 rows x 18 columns]

# %%
data_test = (
    data_test_categorical_features
    .join(data_test_numerical_features)
    
)
data_test
# Out:
#        workclass  education  marital-status  occupation  relationship  race  \
# id
# 27867        3.0       12.0             0.0         9.0           1.0   4.0
# 27868        5.0       11.0             2.0         2.0           0.0   4.0
# 27869        3.0        9.0             2.0         9.0           0.0   1.0
# 27870        4.0       15.0             4.0         7.0           3.0   1.0
# 27871        1.0        7.0             2.0        10.0           0.0   4.0
# ...          ...        ...             ...         ...           ...   ...
# 34862        1.0       15.0             4.0        10.0           1.0   2.0
# 34863        3.0        9.0             4.0        11.0           3.0   4.0
# 34864        1.0        9.0             2.0         9.0           0.0   4.0
# 34865        3.0       11.0             2.0        13.0           0.0   4.0
# 34866        3.0       14.0             4.0         9.0           1.0   4.0
#
#        sex  native-country-code  native-country  social-security-number  \
# id
# 27867  1.0                  0.0             1.0               -0.070140
# 27868  1.0                 36.0            38.0                0.328634
# 27869  1.0                  1.0             2.0                1.203952
# 27870  0.0                 39.0            34.0                0.130615
# 27871  1.0                 36.0            38.0                1.436679
# ...    ...                  ...             ...                     ...
# 34862  1.0                 36.0            38.0               -0.993863
# 34863  1.0                  5.0            10.0               -0.290510
# 34864  1.0                 23.0            25.0               -0.335037
# 34865  1.0                 36.0            38.0               -1.682173
# 34866  0.0                 36.0            38.0                0.909053
#
#        house-number     age-group    fnlwgt  education-num  capitalgain  \
# id
# 27867     -0.284801 -1.775140e-16  0.245956       1.358944    -0.326858
# 27868     -1.178938 -7.277627e-01 -1.221542      -0.559105    -0.326858
# 27869      0.897947  7.168925e-02  0.774717       0.975334    -0.326858
# 27870      0.849030 -1.527215e+00 -0.388883      -0.175495    -0.326858
# 27871     -0.486410 -7.277627e-01 -0.063507       0.591724    -0.326858
# ...             ...           ...       ...            ...          ...
# 34862     -0.048601 -7.277627e-01  0.834739      -0.175495    -0.326858
# 34863      0.535610  7.168925e-02  0.400111       0.975334    -0.326858
# 34864     -1.630374 -7.277627e-01  2.330491       0.975334    -0.326858
# 34865     -0.445180  8.711412e-01  0.580198      -0.559105    -0.326858
# 34866     -1.510527  7.168925e-02 -0.806659       1.742553     3.933366
#
#        capitalloss  hoursperweek
# id
# 27867    -0.234681     -0.048355
# 27868    -0.234681     -0.048355
# 27869    -0.234681     -0.048355
# 27870    -0.234681     -1.189149
# 27871    -0.234681     -0.048355
# ...            ...           ...
# 34862    -0.234681     -0.048355
# 34863    -0.234681     -0.048355
# 34864    -0.234681     -0.048355
# 34865    -0.234681      1.092439
# 34866    -0.234681      1.092439
#
# [7000 rows x 17 columns]

# %% [markdown]
# # Instructions
# - Manually choose a subset of features that you think are most relevant to the classification task
# - Create `pandas.DataFrame`s that contain only those relevant features for training data and test data respectively

# %%
selected_features = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'social-security-number',
    'house-number',
    'fnlwgt',
    'education-num',
    'age-group',
    'capitalgain',
    'capitalloss',
    'hoursperweek',
    'native-country-code',
    'native-country'
    
]

# %%
data_train_feature_selected = data_train[selected_features + ['label']]

# %%
data_test_feature_selected = data_test[selected_features]

# %% [markdown]
# # Instructions
# - Write the train data set to `./data/features.train.csv`
# - Write the test data set to `./data/features.test.csv`

# %%
data_train_feature_selected.to_csv('./data/x_high_salary_features.train.csv')

# %%
data_test_feature_selected.to_csv('./data/x_high_salary_features.test.csv')
