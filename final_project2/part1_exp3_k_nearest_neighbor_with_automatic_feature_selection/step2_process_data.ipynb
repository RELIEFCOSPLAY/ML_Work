# %%
import pandas
import seaborn
import numpy
import sklearn.preprocessing
import sklearn.impute
import sklearn.feature_selection

# %matplotlib inline

# %% [markdown]
# # Instructions
#
# - Read both training and test data from CSV files
# - Then, identify which columns are numerical and which columns are categorical
# - Assess whether the data is balance or imbalance

# %%
data_train = pandas.read_csv('../data/high_salary_failure.train.csv').set_index('id')
data_train
# Out:
#        social-security-number  house-number  age-group    workclass    fnlwgt  \
# id
# 825               418767554.0        5605.0        0.0      private  333838.0
# 7110              781090834.0        7323.0        3.0      private  205100.0
# 4726              973120412.0        5633.0        3.0  federal-gov  305850.0
# 4570              545207638.0        7185.0        2.0      private  182189.0
# 24219             872193378.0        5208.0        1.0    state-gov  208406.0
# ...                       ...           ...        ...          ...       ...
# 10538             224015677.0         941.0        3.0      private  191858.0
# 17709             809202143.0        1882.0        3.0      private  153883.0
# 8432              250265741.0        4299.0        0.0    state-gov  292816.0
# 17322             768375775.0        7525.0        3.0      private   92968.0
# 5625              428964257.0        8547.0        2.0    local-gov  145178.0
#
#           education  education-num      marital-status       occupation  \
# id
# 825         hs-grad            9.0       never-married     adm-clerical
# 7110      assoc-voc           11.0  married-civ-spouse  exec-managerial
# 4726    prof-school           15.0  married-civ-spouse  exec-managerial
# 4570        hs-grad            9.0  married-civ-spouse     craft-repair
# 24219     bachelors           13.0       never-married   prof-specialty
# ...             ...            ...                 ...              ...
# 10538  some-college           10.0  married-civ-spouse     craft-repair
# 17709     bachelors           13.0  married-civ-spouse   prof-specialty
# 8432      assoc-voc           11.0       never-married     adm-clerical
# 17322    assoc-acdm           12.0           separated  exec-managerial
# 5625        hs-grad            9.0  married-civ-spouse    other-service
#
#         relationship   race     sex  capitalgain  capitalloss  hoursperweek  \
# id
# 825    not-in-family  white    male          0.0          0.0           2.0
# 7110         husband  white    male          0.0          0.0           3.0
# 4726         husband  white    male          4.0          0.0           2.0
# 4570         husband  white    male          0.0          2.0           4.0
# 24219  not-in-family  white    male          0.0          0.0           1.0
# ...              ...    ...     ...          ...          ...           ...
# 10538        husband  white    male          0.0          0.0           2.0
# 17709        husband  black    male          3.0          0.0           2.0
# 8432       own-child  white  female          0.0          0.0           2.0
# 17322      unmarried  white  female          0.0          0.0           2.0
# 5625            wife  black  female          0.0          0.0           2.0
#
#       native-country-code native-country  label
# id
# 825                   USA  united-states    0.0
# 7110                  USA  united-states    1.0
# 4726                  USA  united-states    1.0
# 4570                  USA  united-states    1.0
# 24219                 USA  united-states    0.0
# ...                   ...            ...    ...
# 10538                 USA  united-states    0.0
# 17709                 USA  united-states    1.0
# 8432                  USA  united-states    0.0
# 17322                 USA  united-states    0.0
# 5625                  JAM        jamaica    1.0
#
# [15675 rows x 18 columns]

# %%
data_test = pandas.read_csv('../data/high_salary.test_features.csv').set_index('id')
data_test
# Out:
#        social-security-number  house-number  age-group  workclass    fnlwgt  \
# id
# 6111              662660965.0        2488.0        0.0    private  287357.0
# 11214             789857277.0        2764.0        1.0    private  167558.0
# 5554              873295173.0        1334.0        4.0    private   27385.0
# 25131             663939283.0         721.0        2.0  local-gov  153976.0
# 14324             520123609.0        5735.0        3.0    private   20956.0
# ...                       ...           ...        ...        ...       ...
# 25998             581586785.0        2564.0        4.0    private  117898.0
# 8375              949309330.0        3303.0        4.0    private  298546.0
# 13888             476419160.0        4926.0        1.0    private   36340.0
# 4159              270359153.0        4016.0        1.0    private  173473.0
# 9658              578036357.0        7751.0        0.0        NaN  199426.0
#
#           education  education-num      marital-status       occupation  \
# id
# 6111           11th            7.0  married-civ-spouse  protective-serv
# 11214       hs-grad            9.0       never-married            sales
# 5554        hs-grad            9.0  married-civ-spouse  exec-managerial
# 25131       masters           14.0  married-civ-spouse   prof-specialty
# 14324       hs-grad            9.0  married-civ-spouse     craft-repair
# ...             ...            ...                 ...              ...
# 25998     bachelors           13.0  married-civ-spouse  exec-managerial
# 8375        hs-grad            9.0  married-civ-spouse  farming-fishing
# 13888          11th            7.0            divorced    other-service
# 4159        masters           14.0  married-civ-spouse   prof-specialty
# 9658   some-college           10.0       never-married              NaN
#
#         relationship                race     sex  capitalgain  capitalloss  \
# id
# 6111         husband               white    male          0.0          0.0
# 11214      unmarried               white  female          0.0          0.0
# 5554         husband               white    male          0.0          0.0
# 25131        husband               white    male          0.0          0.0
# 14324        husband               white    male          0.0          0.0
# ...              ...                 ...     ...          ...          ...
# 25998        husband               white    male          0.0          0.0
# 8375         husband               white    male          0.0          0.0
# 13888      unmarried               white  female          0.0          0.0
# 4159         husband  asian-pac-islander    male          0.0          0.0
# 9658   not-in-family               white  female          0.0          0.0
#
#        hoursperweek native-country-code native-country
# id
# 6111            2.0                 USA  united-states
# 11214           1.0                 MEX         mexico
# 5554            3.0                 USA  united-states
# 25131           2.0                 USA  united-states
# 14324           2.0                 USA  united-states
# ...             ...                 ...            ...
# 25998           3.0                 USA  united-states
# 8375            4.0                 USA  united-states
# 13888           1.0                 USA  united-states
# 4159            2.0                 USA  united-states
# 9658            2.0                 USA  united-states
#
# [6967 rows x 17 columns]

# %%
data_train.dtypes
# Out:
# social-security-number    float64
# house-number              float64
# age-group                 float64
# workclass                  object
# fnlwgt                    float64
# education                  object
# education-num             float64
# marital-status             object
# occupation                 object
# relationship               object
# race                       object
# sex                        object
# capitalgain               float64
# capitalloss               float64
# hoursperweek              float64
# native-country-code        object
# native-country             object
# label                     float64
# dtype: object

# %%
data_test.dtypes
# Out:
# social-security-number    float64
# house-number              float64
# age-group                 float64
# workclass                  object
# fnlwgt                    float64
# education                  object
# education-num             float64
# marital-status             object
# occupation                 object
# relationship               object
# race                       object
# sex                        object
# capitalgain               float64
# capitalloss               float64
# hoursperweek              float64
# native-country-code        object
# native-country             object
# dtype: object

# %%
categorical_features = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country-code',
    'native-country'
]

for feature in categorical_features:
    possible_values = data_train[feature].unique()
    print(f"{feature:20s} {possible_values.size:2d} {possible_values}")
# Out:
# workclass             9 ['private' 'federal-gov' 'state-gov' 'local-gov' nan 'self-emp-not-inc'
#  'self-emp-inc' 'without-pay' 'never-worked']
# education            17 ['hs-grad' 'assoc-voc' 'prof-school' 'bachelors' 'some-college' '11th'
#  'masters' '5th-6th' 'assoc-acdm' '1st-4th' '10th' '7th-8th' 'doctorate'
#  '12th' '9th' 'preschool' nan]
# marital-status        8 ['never-married' 'married-civ-spouse' 'widowed' 'divorced'
#  'married-spouse-absent' 'separated' 'married-af-spouse' nan]
# occupation           15 ['adm-clerical' 'exec-managerial' 'craft-repair' 'prof-specialty' 'sales'
#  nan 'handlers-cleaners' 'other-service' 'tech-support' 'farming-fishing'
#  'machine-op-inspct' 'transport-moving' 'priv-house-serv' 'armed-forces'
#  'protective-serv']
# relationship          7 ['not-in-family' 'husband' 'own-child' 'other-relative' 'unmarried' 'wife'
#  nan]
# race                  6 ['white' 'asian-pac-islander' 'black' 'amer-indian-eskimo' 'other' nan]
# sex                   3 ['male' 'female' nan]
# native-country-code  40 ['USA' 'PHL' nan 'JPN' 'CAN' 'MEX' 'POL' 'PRT' 'IRL' 'CUB' 'ZAF' 'JAM'
#  'IND' 'LAO' 'COL' 'ITA' 'IRN' 'DUE' 'GBR' 'GTM' 'DOM' 'PRI' 'KHM' 'HTI'
#  'VNM' 'SLV' 'FRA' 'HUN' 'CHN' 'TTO' 'PER' 'ECU' 'TWN' 'HKG' 'YUG' 'THA'
#  'UMI' 'GRC' 'NIC' 'HND']
# native-country       41 ['united-states' 'philippines' nan 'japan' 'canada' 'mexico' 'poland'
#  'portugal' 'ireland' 'cuba' 'south' 'jamaica' 'india' 'laos' 'columbia'
#  'italy' 'iran' 'germany' 'england' 'guatemala' 'dominican-republic'
#  'puerto-rico' 'cambodia' 'haiti' 'vietnam' 'el-salvador' 'france'
#  'hungary' 'china' 'trinadad&tobago' 'peru' 'ecuador' 'taiwan' 'hong'
#  'yugoslavia' 'thailand' 'outlying-us(guam-usvi-etc)' 'greece' 'nicaragua'
#  'scotland' 'honduras']

# %%
numerical_features = [
    'social-security-number',
    'house-number',
    'age-group',
    'fnlwgt',
    'education-num',
    'capitalgain',
    'capitalloss',
    'hoursperweek',
    
]

data_train[numerical_features].describe()
# Out:
#        social-security-number  house-number     age-group        fnlwgt  \
# count            1.566600e+04  15655.000000  15664.000000  1.565900e+04
# mean             5.525061e+08   5054.042031      1.918667  1.886147e+05
# std              2.602983e+08   2869.897683      1.252524  1.035616e+05
# min              1.000850e+08    101.000000      0.000000  1.930200e+04
# 25%              3.222344e+08   2607.000000      1.000000  1.173630e+05
# 50%              5.539719e+08   5006.000000      2.000000  1.775780e+05
# 75%              7.801364e+08   7582.000000      3.000000  2.364770e+05
# max              9.999588e+08   9998.000000      4.000000  1.226583e+06
#
#        education-num   capitalgain   capitalloss  hoursperweek
# count   15664.000000  15656.000000  15658.000000  15658.000000
# mean       10.458823      0.306528      0.153340      2.048921
# std         2.610434      0.936706      0.650184      0.875771
# min         1.000000      0.000000      0.000000      0.000000
# 25%         9.000000      0.000000      0.000000      2.000000
# 50%        10.000000      0.000000      0.000000      2.000000
# 75%        13.000000      0.000000      0.000000      3.000000
# max        16.000000      4.000000      4.000000      4.000000

# %%
data_train['label'].value_counts()
# Out:
# label
# 0.0    9106
# 1.0    6569
# Name: count, dtype: int64

# %%
data_test['race'].value_counts()
# Out:
# race
# white                 6036
# black                  584
# asian-pac-islander     238
# amer-indian-eskimo      60
# other                   42
# Name: count, dtype: int64

# %% [markdown]
# # Instructions
# - Investigate whether the dataset contains any missing data

# %%
data_train.isna().sum(axis='index')
# Out:
# social-security-number      9
# house-number               20
# age-group                  11
# workclass                 803
# fnlwgt                     16
# education                  11
# education-num              11
# marital-status             16
# occupation                802
# relationship               18
# race                       18
# sex                        16
# capitalgain                19
# capitalloss                17
# hoursperweek               17
# native-country-code       292
# native-country            292
# label                       0
# dtype: int64

# %%
data_test.isna().sum(axis='index')
# Out:
# social-security-number      2
# house-number                9
# age-group                  13
# workclass                 345
# fnlwgt                      4
# education                   7
# education-num               8
# marital-status              9
# occupation                347
# relationship               13
# race                        7
# sex                         7
# capitalgain                 8
# capitalloss                10
# hoursperweek               13
# native-country-code       122
# native-country            123
# dtype: int64

# %% [markdown]
# # Instructions
# - Now, preprocess the data before model training
# - Create 3 `pandas.DataFrames`
#     - `pandas.DataFrame` of only ordinal features encoded using `sklearn.preprocessing.OrdinalEncoder`
#     - `pandas.DataFrame` of only numerical features. Also, apply `sklearn.preprocessing.StandardScaler`.
#     - `pandas.DataFrame` of labels encoded using `sklearn.preprocessing.OrdinalEncoder`
#         - Map {`no`, `yes`} to {0, 1} respectively
# - Use `sklearn.impute.SimpleImputer` to handle missing values in each `pandas.DataFrame`
# - Then, combine the 3 `pandas.DataFrame` to obtain the fully processed training and test data
#     - Hint: use `.join`

# %% [markdown]
# ## For categorical features
# - Define a subset of categorical features
# - Use `sklearn.impute.SimpleImputer` to handle missing values by filling in with a majority category from the **training data**
# - Then, Use `sklearn.preprocessing.OrdinalEncoder` to create an ordinal encoder, then fit using the training data
# - Create a new `pandas.DataFrame` of only ordinally encoded features for both training and test data

# %%
categorical_features = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
]

# %%
data_train_categorical_features = data_train[categorical_features]
data_train_categorical_features
# Out:
#          workclass     education      marital-status       occupation  \
# id
# 825        private       hs-grad       never-married     adm-clerical
# 7110       private     assoc-voc  married-civ-spouse  exec-managerial
# 4726   federal-gov   prof-school  married-civ-spouse  exec-managerial
# 4570       private       hs-grad  married-civ-spouse     craft-repair
# 24219    state-gov     bachelors       never-married   prof-specialty
# ...            ...           ...                 ...              ...
# 10538      private  some-college  married-civ-spouse     craft-repair
# 17709      private     bachelors  married-civ-spouse   prof-specialty
# 8432     state-gov     assoc-voc       never-married     adm-clerical
# 17322      private    assoc-acdm           separated  exec-managerial
# 5625     local-gov       hs-grad  married-civ-spouse    other-service
#
#         relationship   race     sex
# id
# 825    not-in-family  white    male
# 7110         husband  white    male
# 4726         husband  white    male
# 4570         husband  white    male
# 24219  not-in-family  white    male
# ...              ...    ...     ...
# 10538        husband  white    male
# 17709        husband  black    male
# 8432       own-child  white  female
# 17322      unmarried  white  female
# 5625            wife  black  female
#
# [15675 rows x 7 columns]

# %%
data_test_categorical_features = data_test[categorical_features]
data_test_categorical_features
# Out:
#        workclass     education      marital-status       occupation  \
# id
# 6111     private          11th  married-civ-spouse  protective-serv
# 11214    private       hs-grad       never-married            sales
# 5554     private       hs-grad  married-civ-spouse  exec-managerial
# 25131  local-gov       masters  married-civ-spouse   prof-specialty
# 14324    private       hs-grad  married-civ-spouse     craft-repair
# ...          ...           ...                 ...              ...
# 25998    private     bachelors  married-civ-spouse  exec-managerial
# 8375     private       hs-grad  married-civ-spouse  farming-fishing
# 13888    private          11th            divorced    other-service
# 4159     private       masters  married-civ-spouse   prof-specialty
# 9658         NaN  some-college       never-married              NaN
#
#         relationship                race     sex
# id
# 6111         husband               white    male
# 11214      unmarried               white  female
# 5554         husband               white    male
# 25131        husband               white    male
# 14324        husband               white    male
# ...              ...                 ...     ...
# 25998        husband               white    male
# 8375         husband               white    male
# 13888      unmarried               white  female
# 4159         husband  asian-pac-islander    male
# 9658   not-in-family               white  female
#
# [6967 rows x 7 columns]

# %%
categorical_imputer = sklearn.impute.SimpleImputer(strategy='most_frequent')
categorical_imputer
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
categorical_imputer.fit(data_train_categorical_features)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
data_train_categorical_features = pandas.DataFrame(
    data    = categorical_imputer.transform(data_train_categorical_features),
    columns = categorical_imputer.get_feature_names_out(),
    index   = data_train_categorical_features.index
)
data_train_categorical_features
# Out:
#          workclass     education      marital-status       occupation  \
# id
# 825        private       hs-grad       never-married     adm-clerical
# 7110       private     assoc-voc  married-civ-spouse  exec-managerial
# 4726   federal-gov   prof-school  married-civ-spouse  exec-managerial
# 4570       private       hs-grad  married-civ-spouse     craft-repair
# 24219    state-gov     bachelors       never-married   prof-specialty
# ...            ...           ...                 ...              ...
# 10538      private  some-college  married-civ-spouse     craft-repair
# 17709      private     bachelors  married-civ-spouse   prof-specialty
# 8432     state-gov     assoc-voc       never-married     adm-clerical
# 17322      private    assoc-acdm           separated  exec-managerial
# 5625     local-gov       hs-grad  married-civ-spouse    other-service
#
#         relationship   race     sex
# id
# 825    not-in-family  white    male
# 7110         husband  white    male
# 4726         husband  white    male
# 4570         husband  white    male
# 24219  not-in-family  white    male
# ...              ...    ...     ...
# 10538        husband  white    male
# 17709        husband  black    male
# 8432       own-child  white  female
# 17322      unmarried  white  female
# 5625            wife  black  female
#
# [15675 rows x 7 columns]

# %%
data_test_categorical_features = pandas.DataFrame(
    data    = categorical_imputer.transform(data_test_categorical_features),
    columns = categorical_imputer.get_feature_names_out(),
    index   = data_test_categorical_features.index
)
data_test_categorical_features
# Out:
#        workclass     education      marital-status       occupation  \
# id
# 6111     private          11th  married-civ-spouse  protective-serv
# 11214    private       hs-grad       never-married            sales
# 5554     private       hs-grad  married-civ-spouse  exec-managerial
# 25131  local-gov       masters  married-civ-spouse   prof-specialty
# 14324    private       hs-grad  married-civ-spouse     craft-repair
# ...          ...           ...                 ...              ...
# 25998    private     bachelors  married-civ-spouse  exec-managerial
# 8375     private       hs-grad  married-civ-spouse  farming-fishing
# 13888    private          11th            divorced    other-service
# 4159     private       masters  married-civ-spouse   prof-specialty
# 9658     private  some-college       never-married   prof-specialty
#
#         relationship                race     sex
# id
# 6111         husband               white    male
# 11214      unmarried               white  female
# 5554         husband               white    male
# 25131        husband               white    male
# 14324        husband               white    male
# ...              ...                 ...     ...
# 25998        husband               white    male
# 8375         husband               white    male
# 13888      unmarried               white  female
# 4159         husband  asian-pac-islander    male
# 9658   not-in-family               white  female
#
# [6967 rows x 7 columns]

# %%
data_train_categorical_features.isna().sum(axis='index')
# Out:
# workclass         0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# dtype: int64

# %%
data_test_categorical_features.isna().sum(axis='index')
# Out:
# workclass         0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# dtype: int64

# %%
ordinal_encoder = sklearn.preprocessing.OrdinalEncoder()
ordinal_encoder
# Out:
# OrdinalEncoder()

# %%
ordinal_encoder.fit(
    X = data_train_categorical_features
)
# Out:
# OrdinalEncoder()

# %%
ordinal_encoder.categories_
# Out:
# [array(['federal-gov', 'local-gov', 'never-worked', 'private',
#         'self-emp-inc', 'self-emp-not-inc', 'state-gov', 'without-pay'],
#        dtype=object),
#  array(['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th', '9th',
#         'assoc-acdm', 'assoc-voc', 'bachelors', 'doctorate', 'hs-grad',
#         'masters', 'preschool', 'prof-school', 'some-college'],
#        dtype=object),
#  array(['divorced', 'married-af-spouse', 'married-civ-spouse',
#         'married-spouse-absent', 'never-married', 'separated', 'widowed'],
#        dtype=object),
#  array(['adm-clerical', 'armed-forces', 'craft-repair', 'exec-managerial',
#         'farming-fishing', 'handlers-cleaners', 'machine-op-inspct',
#         'other-service', 'priv-house-serv', 'prof-specialty',
#         'protective-serv', 'sales', 'tech-support', 'transport-moving'],
#        dtype=object),
#  array(['husband', 'not-in-family', 'other-relative', 'own-child',
#         'unmarried', 'wife'], dtype=object),
#  array(['amer-indian-eskimo', 'asian-pac-islander', 'black', 'other',
#         'white'], dtype=object),
#  array(['female', 'male'], dtype=object)]

# %%
data_train_categorical_features = pandas.DataFrame(
    data    = ordinal_encoder.transform(data_train_categorical_features),
    columns = ordinal_encoder.get_feature_names_out(),
    index   = data_train.index
)
data_train_categorical_features
# Out:
#        workclass  education  marital-status  occupation  relationship  race  \
# id
# 825          3.0       11.0             4.0         0.0           1.0   4.0
# 7110         3.0        8.0             2.0         3.0           0.0   4.0
# 4726         0.0       14.0             2.0         3.0           0.0   4.0
# 4570         3.0       11.0             2.0         2.0           0.0   4.0
# 24219        6.0        9.0             4.0         9.0           1.0   4.0
# ...          ...        ...             ...         ...           ...   ...
# 10538        3.0       15.0             2.0         2.0           0.0   4.0
# 17709        3.0        9.0             2.0         9.0           0.0   2.0
# 8432         6.0        8.0             4.0         0.0           3.0   4.0
# 17322        3.0        7.0             5.0         3.0           4.0   4.0
# 5625         1.0       11.0             2.0         7.0           5.0   2.0
#
#        sex
# id
# 825    1.0
# 7110   1.0
# 4726   1.0
# 4570   1.0
# 24219  1.0
# ...    ...
# 10538  1.0
# 17709  1.0
# 8432   0.0
# 17322  0.0
# 5625   0.0
#
# [15675 rows x 7 columns]

# %%
data_test_categorical_features = pandas.DataFrame(
    data    = ordinal_encoder.transform(data_test_categorical_features),
    columns = ordinal_encoder.get_feature_names_out(),
    index   = data_test.index
)
data_test_categorical_features
# Out:
#        workclass  education  marital-status  occupation  relationship  race  \
# id
# 6111         3.0        1.0             2.0        10.0           0.0   4.0
# 11214        3.0       11.0             4.0        11.0           4.0   4.0
# 5554         3.0       11.0             2.0         3.0           0.0   4.0
# 25131        1.0       12.0             2.0         9.0           0.0   4.0
# 14324        3.0       11.0             2.0         2.0           0.0   4.0
# ...          ...        ...             ...         ...           ...   ...
# 25998        3.0        9.0             2.0         3.0           0.0   4.0
# 8375         3.0       11.0             2.0         4.0           0.0   4.0
# 13888        3.0        1.0             0.0         7.0           4.0   4.0
# 4159         3.0       12.0             2.0         9.0           0.0   1.0
# 9658         3.0       15.0             4.0         9.0           1.0   4.0
#
#        sex
# id
# 6111   1.0
# 11214  0.0
# 5554   1.0
# 25131  1.0
# 14324  1.0
# ...    ...
# 25998  1.0
# 8375   1.0
# 13888  0.0
# 4159   1.0
# 9658   0.0
#
# [6967 rows x 7 columns]

# %% [markdown]
# ## For numerical features
# - Define and select a subset of numerical features for training and test data
# - Use `sklearn.impute.SimpleImputer` to handle missing values by filling in with a mean from the training data
# - Then, standardize the numerical data
#     - Use `seaborn.violinplot` to show a distribution of the numerical data before standardization.
#     - Apply `sklearn.preprocessing.StandardScaler` to create a standard scaler, then fit using the training data
#     - Use `seaborn.violinplot` again to show that the numerical data is properly standardized.
# - Create a new `pandas.DataFrame` of only numerically encoded features for both training and test data

# %%
numerical_features = [
   'social-security-number',
    'house-number',
    'age-group',
    'fnlwgt',
    'education-num',
    'capitalgain',
    'capitalloss',
    'hoursperweek',
    
]

# %%
data_train_numerical_features = data_train[numerical_features]
data_train_numerical_features
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 825               418767554.0        5605.0        0.0  333838.0
# 7110              781090834.0        7323.0        3.0  205100.0
# 4726              973120412.0        5633.0        3.0  305850.0
# 4570              545207638.0        7185.0        2.0  182189.0
# 24219             872193378.0        5208.0        1.0  208406.0
# ...                       ...           ...        ...       ...
# 10538             224015677.0         941.0        3.0  191858.0
# 17709             809202143.0        1882.0        3.0  153883.0
# 8432              250265741.0        4299.0        0.0  292816.0
# 17322             768375775.0        7525.0        3.0   92968.0
# 5625              428964257.0        8547.0        2.0  145178.0
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 825              9.0          0.0          0.0           2.0
# 7110            11.0          0.0          0.0           3.0
# 4726            15.0          4.0          0.0           2.0
# 4570             9.0          0.0          2.0           4.0
# 24219           13.0          0.0          0.0           1.0
# ...              ...          ...          ...           ...
# 10538           10.0          0.0          0.0           2.0
# 17709           13.0          3.0          0.0           2.0
# 8432            11.0          0.0          0.0           2.0
# 17322           12.0          0.0          0.0           2.0
# 5625             9.0          0.0          0.0           2.0
#
# [15675 rows x 8 columns]

# %%
data_test_numerical_features = data_test[numerical_features]
data_test_numerical_features
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 6111              662660965.0        2488.0        0.0  287357.0
# 11214             789857277.0        2764.0        1.0  167558.0
# 5554              873295173.0        1334.0        4.0   27385.0
# 25131             663939283.0         721.0        2.0  153976.0
# 14324             520123609.0        5735.0        3.0   20956.0
# ...                       ...           ...        ...       ...
# 25998             581586785.0        2564.0        4.0  117898.0
# 8375              949309330.0        3303.0        4.0  298546.0
# 13888             476419160.0        4926.0        1.0   36340.0
# 4159              270359153.0        4016.0        1.0  173473.0
# 9658              578036357.0        7751.0        0.0  199426.0
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 6111             7.0          0.0          0.0           2.0
# 11214            9.0          0.0          0.0           1.0
# 5554             9.0          0.0          0.0           3.0
# 25131           14.0          0.0          0.0           2.0
# 14324            9.0          0.0          0.0           2.0
# ...              ...          ...          ...           ...
# 25998           13.0          0.0          0.0           3.0
# 8375             9.0          0.0          0.0           4.0
# 13888            7.0          0.0          0.0           1.0
# 4159            14.0          0.0          0.0           2.0
# 9658            10.0          0.0          0.0           2.0
#
# [6967 rows x 8 columns]

# %%
numerical_imputer = sklearn.impute.SimpleImputer(strategy='mean')
numerical_imputer
# Out:
# SimpleImputer()

# %%
numerical_imputer.fit(data_train_numerical_features)
# Out:
# SimpleImputer()

# %%
data_train_numerical_features = pandas.DataFrame(
    data    = numerical_imputer.transform(data_train_numerical_features),
    columns = numerical_imputer.get_feature_names_out(),
    index   = data_train_numerical_features.index
)
data_train_numerical_features
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 825               418767554.0        5605.0        0.0  333838.0
# 7110              781090834.0        7323.0        3.0  205100.0
# 4726              973120412.0        5633.0        3.0  305850.0
# 4570              545207638.0        7185.0        2.0  182189.0
# 24219             872193378.0        5208.0        1.0  208406.0
# ...                       ...           ...        ...       ...
# 10538             224015677.0         941.0        3.0  191858.0
# 17709             809202143.0        1882.0        3.0  153883.0
# 8432              250265741.0        4299.0        0.0  292816.0
# 17322             768375775.0        7525.0        3.0   92968.0
# 5625              428964257.0        8547.0        2.0  145178.0
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 825              9.0          0.0          0.0           2.0
# 7110            11.0          0.0          0.0           3.0
# 4726            15.0          4.0          0.0           2.0
# 4570             9.0          0.0          2.0           4.0
# 24219           13.0          0.0          0.0           1.0
# ...              ...          ...          ...           ...
# 10538           10.0          0.0          0.0           2.0
# 17709           13.0          3.0          0.0           2.0
# 8432            11.0          0.0          0.0           2.0
# 17322           12.0          0.0          0.0           2.0
# 5625             9.0          0.0          0.0           2.0
#
# [15675 rows x 8 columns]

# %%
data_test_numerical_features = pandas.DataFrame(
    data    = numerical_imputer.transform(data_test_numerical_features),
    columns = numerical_imputer.get_feature_names_out(),
    index   = data_test_numerical_features.index
)
data_test_numerical_features
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 6111              662660965.0        2488.0        0.0  287357.0
# 11214             789857277.0        2764.0        1.0  167558.0
# 5554              873295173.0        1334.0        4.0   27385.0
# 25131             663939283.0         721.0        2.0  153976.0
# 14324             520123609.0        5735.0        3.0   20956.0
# ...                       ...           ...        ...       ...
# 25998             581586785.0        2564.0        4.0  117898.0
# 8375              949309330.0        3303.0        4.0  298546.0
# 13888             476419160.0        4926.0        1.0   36340.0
# 4159              270359153.0        4016.0        1.0  173473.0
# 9658              578036357.0        7751.0        0.0  199426.0
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 6111             7.0          0.0          0.0           2.0
# 11214            9.0          0.0          0.0           1.0
# 5554             9.0          0.0          0.0           3.0
# 25131           14.0          0.0          0.0           2.0
# 14324            9.0          0.0          0.0           2.0
# ...              ...          ...          ...           ...
# 25998           13.0          0.0          0.0           3.0
# 8375             9.0          0.0          0.0           4.0
# 13888            7.0          0.0          0.0           1.0
# 4159            14.0          0.0          0.0           2.0
# 9658            10.0          0.0          0.0           2.0
#
# [6967 rows x 8 columns]

# %%
data_train_numerical_features.isna().sum(axis='index')
# Out:
# social-security-number    0
# house-number              0
# age-group                 0
# fnlwgt                    0
# education-num             0
# capitalgain               0
# capitalloss               0
# hoursperweek              0
# dtype: int64

# %%
data_test_numerical_features.isna().sum(axis='index')
# Out:
# social-security-number    0
# house-number              0
# age-group                 0
# fnlwgt                    0
# education-num             0
# capitalgain               0
# capitalloss               0
# hoursperweek              0
# dtype: int64

# %%
axes = seaborn.violinplot(
    data_train_numerical_features,
    order = numerical_features
)
axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# Out:
# /tmp/ipykernel_8277/1656974928.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# [Text(0, 0, 'social-security-number'),
#  Text(1, 0, 'house-number'),
#  Text(2, 0, 'age-group'),
#  Text(3, 0, 'fnlwgt'),
#  Text(4, 0, 'education-num'),
#  Text(5, 0, 'capitalgain'),
#  Text(6, 0, 'capitalloss'),
#  Text(7, 0, 'hoursperweek')]

# %%
axes = seaborn.violinplot(
    data_test_numerical_features,
    order = numerical_features
)
axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# Out:
# /tmp/ipykernel_8277/439515287.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# [Text(0, 0, 'social-security-number'),
#  Text(1, 0, 'house-number'),
#  Text(2, 0, 'age-group'),
#  Text(3, 0, 'fnlwgt'),
#  Text(4, 0, 'education-num'),
#  Text(5, 0, 'capitalgain'),
#  Text(6, 0, 'capitalloss'),
#  Text(7, 0, 'hoursperweek')]

# %%
standard_scaler = sklearn.preprocessing.StandardScaler()
standard_scaler
# Out:
# StandardScaler()

# %%
standard_scaler.fit(data_train_numerical_features)
# Out:
# StandardScaler()

# %%
data_train_numerical_features = pandas.DataFrame(
    data    = standard_scaler.transform(data_train_numerical_features),
    columns = standard_scaler.get_feature_names_out(),
    index   = data_train_numerical_features.index
)
data_train_numerical_features
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 825                 -0.513954      0.192107  -1.532427  1.403050
# 7110                 0.878445      0.791136   0.863654  0.159270
# 4726                 1.616409      0.201870   0.863654  1.132649
# 4570                -0.028048      0.743018   0.064960 -0.062081
# 24219                1.228550      0.053682  -0.733733  0.191211
# ...                       ...           ...        ...       ...
# 10538               -1.262380     -1.434128   0.863654  0.031335
# 17709                0.986476     -1.106022   0.863654 -0.335554
# 8432                -1.161501     -0.263267  -1.532427  1.006723
# 17322                0.829581      0.861569   0.863654 -0.924074
# 5625                -0.474768      1.217918   0.064960 -0.419656
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 825        -0.559057    -0.327449    -0.235977     -0.055892
# 7110        0.207392    -0.327449    -0.235977      1.086615
# 4726        1.740291     3.945562    -0.235977     -0.055892
# 4570       -0.559057    -0.327449     2.841843      2.229122
# 24219       0.973842    -0.327449    -0.235977     -1.198399
# ...              ...          ...          ...           ...
# 10538      -0.175832    -0.327449    -0.235977     -0.055892
# 17709       0.973842     2.877309    -0.235977     -0.055892
# 8432        0.207392    -0.327449    -0.235977     -0.055892
# 17322       0.590617    -0.327449    -0.235977     -0.055892
# 5625       -0.559057    -0.327449    -0.235977     -0.055892
#
# [15675 rows x 8 columns]

# %%
data_test_numerical_features = pandas.DataFrame(
    data    = standard_scaler.transform(data_test_numerical_features),
    columns = standard_scaler.get_feature_names_out(),
    index   = data_test_numerical_features.index
)
data_test_numerical_features
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 6111                 0.423322     -0.894723  -1.532427  0.953982
# 11214                0.912134     -0.798488  -0.733733 -0.203435
# 5554                 1.232784     -1.297097   1.662347 -1.557693
# 25131                0.428235     -1.510837   0.064960 -0.334656
# 14324               -0.124445      0.237435   0.863654 -1.619806
# ...                       ...           ...        ...       ...
# 25998                0.111756     -0.868223   1.662347 -0.683217
# 8375                 1.524904     -0.610550   1.662347  1.062083
# 13888               -0.292400     -0.044645  -0.733733 -1.471176
# 4159                -1.084283     -0.361943  -0.733733 -0.146289
# 9658                 0.098112      0.940370  -1.532427  0.104452
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 6111       -1.325506    -0.327449    -0.235977     -0.055892
# 11214      -0.559057    -0.327449    -0.235977     -1.198399
# 5554       -0.559057    -0.327449    -0.235977      1.086615
# 25131       1.357067    -0.327449    -0.235977     -0.055892
# 14324      -0.559057    -0.327449    -0.235977     -0.055892
# ...              ...          ...          ...           ...
# 25998       0.973842    -0.327449    -0.235977      1.086615
# 8375       -0.559057    -0.327449    -0.235977      2.229122
# 13888      -1.325506    -0.327449    -0.235977     -1.198399
# 4159        1.357067    -0.327449    -0.235977     -0.055892
# 9658       -0.175832    -0.327449    -0.235977     -0.055892
#
# [6967 rows x 8 columns]

# %%
axes = seaborn.violinplot(
    data_train_numerical_features,
    order = numerical_features
)
axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# Out:
# /tmp/ipykernel_8277/1656974928.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# [Text(0, 0, 'social-security-number'),
#  Text(1, 0, 'house-number'),
#  Text(2, 0, 'age-group'),
#  Text(3, 0, 'fnlwgt'),
#  Text(4, 0, 'education-num'),
#  Text(5, 0, 'capitalgain'),
#  Text(6, 0, 'capitalloss'),
#  Text(7, 0, 'hoursperweek')]

# %%
axes = seaborn.violinplot(
    data_test_numerical_features,
    order = numerical_features
)
axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# Out:
# /tmp/ipykernel_8277/439515287.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# [Text(0, 0, 'social-security-number'),
#  Text(1, 0, 'house-number'),
#  Text(2, 0, 'age-group'),
#  Text(3, 0, 'fnlwgt'),
#  Text(4, 0, 'education-num'),
#  Text(5, 0, 'capitalgain'),
#  Text(6, 0, 'capitalloss'),
#  Text(7, 0, 'hoursperweek')]

# %% [markdown]
# ## For labels
# - Use `sklearn.preprocessing.OrdinalEncoder` to create an ordinal encoder, then fit using the training data
#     - Map {`no`, `yes`} to {0, 1} respectively
# - Create a new `pandas.DataFrame` of ordinally encoded labels for both training and test data

# %%
label_encoder = sklearn.preprocessing.OrdinalEncoder(categories=[['0.0', '1.0',]])
label_encoder
# Out:
# OrdinalEncoder(categories=[['0.0', '1.0']])

# %%
label_encoder.fit(data_train[['label']])
# Out:
# OrdinalEncoder(categories=[['0.0', '1.0']])

# %%
data_train_label = pandas.DataFrame(
    data    = label_encoder.transform(data_train[['label']]),
    columns = ['label'],
    index   = data_train.index
)
data_train_label
# Out:
#        label
# id
# 825      0.0
# 7110     1.0
# 4726     1.0
# 4570     1.0
# 24219    0.0
# ...      ...
# 10538    0.0
# 17709    1.0
# 8432     0.0
# 17322    0.0
# 5625     1.0
#
# [15675 rows x 1 columns]

# %%
data_test_label = pandas.DataFrame(
    data    = label_encoder.transform(data_test[['label']]),
    columns = ['label'],
    index   = data_test.index
)
data_test_label
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 2
#       1 data_test_label = pandas.DataFrame(
# ----> 2     data    = label_encoder.transform(data_test[['label']]),
#       3     columns = ['label'],
#       4     index   = data_test.index
#       5 )
#       6 data_test_label
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:6175, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     if use_interval_msg:
#    6174         key = list(key)
# -> 6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['label'], dtype='object')] are in the [columns]"

# %% [markdown]
# ## Reconstruction of data sets
# - Combine the 3 `pandas.DataFrame` to obtain the fully processed training and test data
#     - Hint: use `.join`

# %%
data_train = (
    data_train_categorical_features
        .join(data_train_numerical_features)
        .join(data_train_label)
)
data_train
# Out:
#        workclass  education  marital-status  occupation  relationship  race  \
# id
# 825          3.0       11.0             4.0         0.0           1.0   4.0
# 7110         3.0        8.0             2.0         3.0           0.0   4.0
# 4726         0.0       14.0             2.0         3.0           0.0   4.0
# 4570         3.0       11.0             2.0         2.0           0.0   4.0
# 24219        6.0        9.0             4.0         9.0           1.0   4.0
# ...          ...        ...             ...         ...           ...   ...
# 10538        3.0       15.0             2.0         2.0           0.0   4.0
# 17709        3.0        9.0             2.0         9.0           0.0   2.0
# 8432         6.0        8.0             4.0         0.0           3.0   4.0
# 17322        3.0        7.0             5.0         3.0           4.0   4.0
# 5625         1.0       11.0             2.0         7.0           5.0   2.0
#
#        sex  social-security-number  house-number  age-group    fnlwgt  \
# id
# 825    1.0               -0.513954      0.192107  -1.532427  1.403050
# 7110   1.0                0.878445      0.791136   0.863654  0.159270
# 4726   1.0                1.616409      0.201870   0.863654  1.132649
# 4570   1.0               -0.028048      0.743018   0.064960 -0.062081
# 24219  1.0                1.228550      0.053682  -0.733733  0.191211
# ...    ...                     ...           ...        ...       ...
# 10538  1.0               -1.262380     -1.434128   0.863654  0.031335
# 17709  1.0                0.986476     -1.106022   0.863654 -0.335554
# 8432   0.0               -1.161501     -0.263267  -1.532427  1.006723
# 17322  0.0                0.829581      0.861569   0.863654 -0.924074
# 5625   0.0               -0.474768      1.217918   0.064960 -0.419656
#
#        education-num  capitalgain  capitalloss  hoursperweek  label
# id
# 825        -0.559057    -0.327449    -0.235977     -0.055892    0.0
# 7110        0.207392    -0.327449    -0.235977      1.086615    1.0
# 4726        1.740291     3.945562    -0.235977     -0.055892    1.0
# 4570       -0.559057    -0.327449     2.841843      2.229122    1.0
# 24219       0.973842    -0.327449    -0.235977     -1.198399    0.0
# ...              ...          ...          ...           ...    ...
# 10538      -0.175832    -0.327449    -0.235977     -0.055892    0.0
# 17709       0.973842     2.877309    -0.235977     -0.055892    1.0
# 8432        0.207392    -0.327449    -0.235977     -0.055892    0.0
# 17322       0.590617    -0.327449    -0.235977     -0.055892    0.0
# 5625       -0.559057    -0.327449    -0.235977     -0.055892    1.0
#
# [15675 rows x 16 columns]

# %%
data_test = (
    data_test_categorical_features
        .join(data_test_numerical_features)
       
)
data_test
# Out:
#        workclass  education  marital-status  occupation  relationship  race  \
# id
# 6111         3.0        1.0             2.0        10.0           0.0   4.0
# 11214        3.0       11.0             4.0        11.0           4.0   4.0
# 5554         3.0       11.0             2.0         3.0           0.0   4.0
# 25131        1.0       12.0             2.0         9.0           0.0   4.0
# 14324        3.0       11.0             2.0         2.0           0.0   4.0
# ...          ...        ...             ...         ...           ...   ...
# 25998        3.0        9.0             2.0         3.0           0.0   4.0
# 8375         3.0       11.0             2.0         4.0           0.0   4.0
# 13888        3.0        1.0             0.0         7.0           4.0   4.0
# 4159         3.0       12.0             2.0         9.0           0.0   1.0
# 9658         3.0       15.0             4.0         9.0           1.0   4.0
#
#        sex  social-security-number  house-number  age-group    fnlwgt  \
# id
# 6111   1.0                0.423322     -0.894723  -1.532427  0.953982
# 11214  0.0                0.912134     -0.798488  -0.733733 -0.203435
# 5554   1.0                1.232784     -1.297097   1.662347 -1.557693
# 25131  1.0                0.428235     -1.510837   0.064960 -0.334656
# 14324  1.0               -0.124445      0.237435   0.863654 -1.619806
# ...    ...                     ...           ...        ...       ...
# 25998  1.0                0.111756     -0.868223   1.662347 -0.683217
# 8375   1.0                1.524904     -0.610550   1.662347  1.062083
# 13888  0.0               -0.292400     -0.044645  -0.733733 -1.471176
# 4159   1.0               -1.084283     -0.361943  -0.733733 -0.146289
# 9658   0.0                0.098112      0.940370  -1.532427  0.104452
#
#        education-num  capitalgain  capitalloss  hoursperweek
# id
# 6111       -1.325506    -0.327449    -0.235977     -0.055892
# 11214      -0.559057    -0.327449    -0.235977     -1.198399
# 5554       -0.559057    -0.327449    -0.235977      1.086615
# 25131       1.357067    -0.327449    -0.235977     -0.055892
# 14324      -0.559057    -0.327449    -0.235977     -0.055892
# ...              ...          ...          ...           ...
# 25998       0.973842    -0.327449    -0.235977      1.086615
# 8375       -0.559057    -0.327449    -0.235977      2.229122
# 13888      -1.325506    -0.327449    -0.235977     -1.198399
# 4159        1.357067    -0.327449    -0.235977     -0.055892
# 9658       -0.175832    -0.327449    -0.235977     -0.055892
#
# [6967 rows x 15 columns]

# %% [markdown]
# # Instruction
#
# - Define a `sklearn.neighbors.KNeighborsClassifier` model with the following configurations to be used as an estimator
# ```
#         n_neighbors = 5,
#         weights     = 'uniform',
#         p           = 2,
# ```
#
# - Use `sklearn.feature_selection.SequentialFeatureSelector` with the following configurations for automatic feature selection
#
# ```
#         estimator            = model,
#         n_features_to_select = 4,
#         direction            = 'backward'
#
# ```
#
# - Now, fit the feature selector to the training data

# %%
model = sklearn.neighbors.KNeighborsClassifier(
        n_neighbors=5,
        weights='uniform', 
        p= 2, 
)
model
# Out:
# KNeighborsClassifier()

# %%
feature_selection = sklearn.feature_selection.SequentialFeatureSelector(
        estimator= model,
        n_features_to_select=4,
        direction= 'backward' 
)
feature_selection
# Out:
# SequentialFeatureSelector(direction='backward',
#                           estimator=KNeighborsClassifier(),
#                           n_features_to_select=4)

# %%
feature_selection.fit(
    X=data_train.drop(['label'], axis='columns'),
    y=data_train['label'],
)
# Out:
# SequentialFeatureSelector(direction='backward',
#                           estimator=KNeighborsClassifier(),
#                           n_features_to_select=4)

# %% [markdown]
# # Instructions
# - Use `.get_feature_names_out()` to get the optimal subset of features from the feature selector
# - Create `pandas.DataFrame`s that contain only those selected features for training data and test data respectively

# %%
selected_features = feature_selection.get_feature_names_out().tolist()
selected_features

# %%
data_train_feature_selected = data_train[selected_features + ['label']]

# %%
data_test_feature_selected = data_test[selected_features]

# %% [markdown]
# # Instructions
# - Write the train data set to `./data/features.train.csv`
# - Write the test data set to `./data/features.test.csv`

# %%
data_train_feature_selected.to_csv('./data/p_high_salary_features.train.csv')

# %%
data_test_feature_selected.to_csv('./data/p_high_salary_features.test.csv')
